# %% [markdown]
# In this notebook I will attempt to observe the values for the optimal alpha given the quadratic approximation of the loss for a mini batch
# $L(\theta) \approx q(\theta):=\frac{1}{2}\left(\theta-\theta_0\right)^{\top} H\left(\theta-\theta_0\right)+\left(\theta-\theta_0\right)^{\top} \cdot g+c$
#
#
# along a direction d
#
# $h(\alpha)=q\left(\theta_0+\alpha \cdot d\right)$
#
#
# which is
# $\alpha^*=\frac{-d^{\top} g}{d^{\top} H d}$

# %% [markdown]
# First we define a simple model:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple neural network
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(10, 5)
        self.fc2 = nn.Linear(5, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Create a simple dataset
X = torch.randn(1000, 10)
y = torch.randn(1000, 1)

# Initialize the model and optimizer
model = SimpleNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# Training loop
n_epochs = 100
batch_size = 32

# %% [markdown]
# Then we train using Adam and try to observe d from adam:

# %%
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        # Get mini-batch
        X_batch = X[i:i+batch_size]
        y_batch = y[i:i+batch_size]

        # Forward pass
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)

        # Backward pass
        optimizer.zero_grad()
        loss.backward()

        # Compute the direction d before the optimizer step
        d = {}
        for name, param in model.named_parameters():
            if param.grad is not None:
                if param not in optimizer.state:
                    # Initialize state if it doesn't exist
                    optimizer.state[param]['exp_avg'] = torch.zeros_like(param.data)
                    optimizer.state[param]['exp_avg_sq'] = torch.zeros_like(param.data)
                    optimizer.state[param]['step'] = torch.tensor(0)  # Initialize as tensor

                # Ensure 'step' is a tensor
                if isinstance(optimizer.state[param]['step'], int):
                    optimizer.state[param]['step'] = torch.tensor(optimizer.state[param]['step'])

                m_t = optimizer.state[param]['exp_avg']  # exponential moving avg of the gradient
                v_t = optimizer.state[param]['exp_avg_sq'] # exp moving avg of the squared gradient
        
                # Bias correction
                beta1, beta2 = optimizer.defaults['betas']
                optimizer.state[param]['step'] += 1  # Increment step as tensor
                t = optimizer.state[param]['step'].item()  # Convert step tensor to int
                # m_t und v_t sind richtung 0 biased bei ersten Iterationen, deshalb teilen wir durch 1-beta^t
                m_t_hat = m_t / (1 - beta1**t) 
                v_t_hat = v_t / (1 - beta2**t)
        
                # Compute direction
                # epsilon verhindert division by zero
                # Adam Step: Theta_t = Theta_t-1 - (alpha_t * m_hat_t / sqrt(v_hat_t) + epsilon) 
                # Dabei wird alpha auch berechnet, lassen wir hier aber aus
                d[name] = -m_t_hat / (torch.sqrt(v_t_hat) + optimizer.defaults['eps']) 

        # Optimizer step
        optimizer.step()


        # Print the direction for the first parameter (for demonstration)
        if i == 0:
            print(f"Epoch {epoch}, Batch 0:")
            for name, direction in d.items():
                print(f"Direction for {name}: {direction.norm()}")

    # Print epoch loss
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

print("Training complete!")
# Out:
# Epoch 0, Batch 0:
# Direction for fc1.weight: 0.0
# Direction for fc1.bias: 0.0
# Direction for fc2.weight: 0.0
# Direction for fc2.bias: 0.0
# Epoch 0, Loss: 2.3547916412353516
# Epoch 1, Batch 0:
# Direction for fc1.weight: 4.373355865478516
# Direction for fc1.bias: 2.5503242015838623
# Direction for fc2.weight: 2.0329806804656982
# Direction for fc2.bias: 1.2113134860992432
# Epoch 2, Batch 0:
# Direction for fc1.weight: 4.390522480010986
# Direction for fc1.bias: 2.5649569034576416
# Direction for fc2.weight: 1.7541961669921875
# Direction for fc2.bias: 1.0527496337890625
# Epoch 3, Batch 0:
# Direction for fc1.weight: 4.001357555389404
# Direction for fc1.bias: 2.2361676692962646
# Direction for fc2.weight: 1.4126876592636108
# Direction for fc2.bias: 0.8529586791992188
# Epoch 4, Batch 0:
# Direction for fc1.weight: 3.7569453716278076
# Direction for fc1.bias: 1.7752281427383423
# Direction for fc2.weight: 1.1067380905151367
# Direction for fc2.bias: 0.6769903302192688
# Epoch 5, Batch 0:
# Direction for fc1.weight: 3.5326473712921143
# Direction for fc1.bias: 1.411535382270813
# Direction for fc2.weight: 0.876738429069519
# Direction for fc2.bias: 0.5369216799736023
# Epoch 6, Batch 0:
# Direction for fc1.weight: 3.323079824447632
# Direction for fc1.bias: 1.1346851587295532
# Direction for fc2.weight: 0.7330880761146545
# Direction for fc2.bias: 0.4317087233066559
# Epoch 7, Batch 0:
# Direction for fc1.weight: 3.1614105701446533
# Direction for fc1.bias: 1.0847270488739014
# Direction for fc2.weight: 0.6618204116821289
# Direction for fc2.bias: 0.35747259855270386
# Epoch 8, Batch 0:
# Direction for fc1.weight: 2.960240364074707
# Direction for fc1.bias: 0.9606181383132935
# Direction for fc2.weight: 0.6419152617454529
# Direction for fc2.bias: 0.3057667315006256
# Epoch 9, Batch 0:
# Direction for fc1.weight: 2.8630282878875732
# Direction for fc1.bias: 0.9030314683914185
# Direction for fc2.weight: 0.6496877074241638
# Direction for fc2.bias: 0.269210547208786
# Epoch 10, Batch 0:
# Direction for fc1.weight: 2.7938907146453857
# Direction for fc1.bias: 0.8814646601676941
# Direction for fc2.weight: 0.6723861694335938
# Direction for fc2.bias: 0.24173785746097565
# Epoch 10, Loss: 1.9833507537841797
# Epoch 11, Batch 0:
# Direction for fc1.weight: 2.69722056388855
# Direction for fc1.bias: 0.8076104521751404
# Direction for fc2.weight: 0.7057974934577942
# Direction for fc2.bias: 0.22010335326194763
# Epoch 12, Batch 0:
# Direction for fc1.weight: 2.5653886795043945
# Direction for fc1.bias: 0.7174241542816162
# Direction for fc2.weight: 0.7383325695991516
# Direction for fc2.bias: 0.20169605314731598
# Epoch 13, Batch 0:
# Direction for fc1.weight: 2.5184121131896973
# Direction for fc1.bias: 0.6871668696403503
# Direction for fc2.weight: 0.7728438973426819
# Direction for fc2.bias: 0.18571563065052032
# Epoch 14, Batch 0:
# Direction for fc1.weight: 2.5097897052764893
# Direction for fc1.bias: 0.6715469360351562
# Direction for fc2.weight: 0.8066308498382568
# Direction for fc2.bias: 0.17366911470890045
# Epoch 15, Batch 0:
# Direction for fc1.weight: 2.5359206199645996
# Direction for fc1.bias: 0.6783190369606018
# Direction for fc2.weight: 0.8399408459663391
# Direction for fc2.bias: 0.16425681114196777
# Epoch 16, Batch 0:
# Direction for fc1.weight: 2.465794324874878
# Direction for fc1.bias: 0.6881065964698792
# Direction for fc2.weight: 0.8718065619468689
# Direction for fc2.bias: 0.15623292326927185
# Epoch 17, Batch 0:
# Direction for fc1.weight: 2.5379791259765625
# Direction for fc1.bias: 0.7169305086135864
# Direction for fc2.weight: 0.9026157855987549
# Direction for fc2.bias: 0.14856769144535065
# Epoch 18, Batch 0:
# Direction for fc1.weight: 2.9216015338897705
# Direction for fc1.bias: 0.59425288438797
# Direction for fc2.weight: 0.9252105951309204
# Direction for fc2.bias: 0.14268158376216888
# Epoch 19, Batch 0:
# Direction for fc1.weight: 2.502960205078125
# Direction for fc1.bias: 0.7656910419464111
# Direction for fc2.weight: 0.9438785910606384
# Direction for fc2.bias: 0.13572946190834045
# Epoch 20, Batch 0:
# Direction for fc1.weight: 2.4633285999298096
# Direction for fc1.bias: 0.7177832126617432
# Direction for fc2.weight: 0.9614574313163757
# Direction for fc2.bias: 0.13178518414497375
# Epoch 20, Loss: 1.928268313407898
# Epoch 21, Batch 0:
# Direction for fc1.weight: 2.3671505451202393
# Direction for fc1.bias: 0.6265462040901184
# Direction for fc2.weight: 0.9728333353996277
# Direction for fc2.bias: 0.1277475506067276
# Epoch 22, Batch 0:
# Direction for fc1.weight: 2.948551654815674
# Direction for fc1.bias: 0.47443869709968567
# Direction for fc2.weight: 0.9762144088745117
# Direction for fc2.bias: 0.12408262491226196
# Epoch 23, Batch 0:
# Direction for fc1.weight: 2.3507156372070312
# Direction for fc1.bias: 0.568134605884552
# Direction for fc2.weight: 0.9871827363967896
# Direction for fc2.bias: 0.11884268373250961
# Epoch 24, Batch 0:
# Direction for fc1.weight: 2.4340977668762207
# Direction for fc1.bias: 0.30175745487213135
# Direction for fc2.weight: 0.9863265156745911
# Direction for fc2.bias: 0.11646953970193863
# Epoch 25, Batch 0:
# Direction for fc1.weight: 2.509725332260132
# Direction for fc1.bias: 0.45925551652908325
# Direction for fc2.weight: 0.986495316028595
# Direction for fc2.bias: 0.11298983544111252
# Epoch 26, Batch 0:
# Direction for fc1.weight: 2.3594629764556885
# Direction for fc1.bias: 0.39057859778404236
# Direction for fc2.weight: 0.9791350960731506
# Direction for fc2.bias: 0.11372416466474533
# Epoch 27, Batch 0:
# Direction for fc1.weight: 2.970870018005371
# Direction for fc1.bias: 0.4278077483177185
# Direction for fc2.weight: 0.9636221528053284
# Direction for fc2.bias: 0.11087155342102051
# Epoch 28, Batch 0:
# Direction for fc1.weight: 2.2520265579223633
# Direction for fc1.bias: 0.542568564414978
# Direction for fc2.weight: 0.9500749707221985
# Direction for fc2.bias: 0.10441220551729202
# Epoch 29, Batch 0:
# Direction for fc1.weight: 2.3849854469299316
# Direction for fc1.bias: 0.39456018805503845
# Direction for fc2.weight: 0.9318512082099915
# Direction for fc2.bias: 0.10325495153665543
# Epoch 30, Batch 0:
# Direction for fc1.weight: 2.461775064468384
# Direction for fc1.bias: 0.4491191506385803
# Direction for fc2.weight: 0.9188642501831055
# Direction for fc2.bias: 0.10024957358837128
# Epoch 30, Loss: 1.880347728729248
# Epoch 31, Batch 0:
# Direction for fc1.weight: 2.3432371616363525
# Direction for fc1.bias: 0.3252514600753784
# Direction for fc2.weight: 0.9028304219245911
# Direction for fc2.bias: 0.09798271209001541
# Epoch 32, Batch 0:
# Direction for fc1.weight: 2.3224403858184814
# Direction for fc1.bias: 0.3223828673362732
# Direction for fc2.weight: 0.8882317543029785
# Direction for fc2.bias: 0.09282241016626358
# Epoch 33, Batch 0:
# Direction for fc1.weight: 2.428230047225952
# Direction for fc1.bias: 0.43237465620040894
# Direction for fc2.weight: 0.8745945692062378
# Direction for fc2.bias: 0.08864346146583557
# Epoch 34, Batch 0:
# Direction for fc1.weight: 2.3365159034729004
# Direction for fc1.bias: 0.4003395736217499
# Direction for fc2.weight: 0.8589088320732117
# Direction for fc2.bias: 0.08634023368358612
# Epoch 35, Batch 0:
# Direction for fc1.weight: 2.512158155441284
# Direction for fc1.bias: 0.4484367072582245
# Direction for fc2.weight: 0.8472418785095215
# Direction for fc2.bias: 0.08099973201751709
# Epoch 36, Batch 0:
# Direction for fc1.weight: 2.359858989715576
# Direction for fc1.bias: 0.43463197350502014
# Direction for fc2.weight: 0.8348900079727173
# Direction for fc2.bias: 0.07780040055513382
# Epoch 37, Batch 0:
# Direction for fc1.weight: 2.3849754333496094
# Direction for fc1.bias: 0.40412774682044983
# Direction for fc2.weight: 0.8238801956176758
# Direction for fc2.bias: 0.07450709491968155
# Epoch 38, Batch 0:
# Direction for fc1.weight: 2.477689266204834
# Direction for fc1.bias: 0.5658693313598633
# Direction for fc2.weight: 0.8134210705757141
# Direction for fc2.bias: 0.07116608321666718
# Epoch 39, Batch 0:
# Direction for fc1.weight: 2.3033645153045654
# Direction for fc1.bias: 0.4453027844429016
# Direction for fc2.weight: 0.8010196089744568
# Direction for fc2.bias: 0.07019580155611038
# Epoch 40, Batch 0:
# Direction for fc1.weight: 2.22788143157959
# Direction for fc1.bias: 0.5674107670783997
# Direction for fc2.weight: 0.7886693477630615
# Direction for fc2.bias: 0.06816712021827698
# Epoch 40, Loss: 1.8534663915634155
# Epoch 41, Batch 0:
# Direction for fc1.weight: 2.4566752910614014
# Direction for fc1.bias: 0.47141775488853455
# Direction for fc2.weight: 0.7710313200950623
# Direction for fc2.bias: 0.06788621097803116
# Epoch 42, Batch 0:
# Direction for fc1.weight: 2.358757495880127
# Direction for fc1.bias: 0.4399266242980957
# Direction for fc2.weight: 0.764275848865509
# Direction for fc2.bias: 0.06585795432329178
# Epoch 43, Batch 0:
# Direction for fc1.weight: 2.7320096492767334
# Direction for fc1.bias: 0.3455791771411896
# Direction for fc2.weight: 0.7551390528678894
# Direction for fc2.bias: 0.064373679459095
# Epoch 44, Batch 0:
# Direction for fc1.weight: 2.4901938438415527
# Direction for fc1.bias: 0.45966869592666626
# Direction for fc2.weight: 0.7474510073661804
# Direction for fc2.bias: 0.059105370193719864
# Epoch 45, Batch 0:
# Direction for fc1.weight: 2.2725186347961426
# Direction for fc1.bias: 0.4353412389755249
# Direction for fc2.weight: 0.7369888424873352
# Direction for fc2.bias: 0.05932722985744476
# Epoch 46, Batch 0:
# Direction for fc1.weight: 2.4002366065979004
# Direction for fc1.bias: 0.37344473600387573
# Direction for fc2.weight: 0.7280667424201965
# Direction for fc2.bias: 0.057266965508461
# Epoch 47, Batch 0:
# Direction for fc1.weight: 2.4819998741149902
# Direction for fc1.bias: 0.5107963681221008
# Direction for fc2.weight: 0.7200321555137634
# Direction for fc2.bias: 0.05490255728363991
# Epoch 48, Batch 0:
# Direction for fc1.weight: 2.3846652507781982
# Direction for fc1.bias: 0.34955060482025146
# Direction for fc2.weight: 0.7141660451889038
# Direction for fc2.bias: 0.05391719192266464
# Epoch 49, Batch 0:
# Direction for fc1.weight: 2.809729814529419
# Direction for fc1.bias: 0.552729606628418
# Direction for fc2.weight: 0.7040776014328003
# Direction for fc2.bias: 0.052162088453769684
# Epoch 50, Batch 0:
# Direction for fc1.weight: 2.344369649887085
# Direction for fc1.bias: 0.3589980900287628
# Direction for fc2.weight: 0.7032755017280579
# Direction for fc2.bias: 0.045316074043512344
# Epoch 50, Loss: 1.8152008056640625
# Epoch 51, Batch 0:
# Direction for fc1.weight: 2.4689550399780273
# Direction for fc1.bias: 0.44295021891593933
# Direction for fc2.weight: 0.6964861154556274
# Direction for fc2.bias: 0.04476465284824371
# Epoch 52, Batch 0:
# Direction for fc1.weight: 2.2377893924713135
# Direction for fc1.bias: 0.3986944854259491
# Direction for fc2.weight: 0.6900762319564819
# Direction for fc2.bias: 0.044461071491241455
# Epoch 53, Batch 0:
# Direction for fc1.weight: 2.454497814178467
# Direction for fc1.bias: 0.43716803193092346
# Direction for fc2.weight: 0.6833941340446472
# Direction for fc2.bias: 0.041096512228250504
# Epoch 54, Batch 0:
# Direction for fc1.weight: 2.5432207584381104
# Direction for fc1.bias: 0.4186237156391144
# Direction for fc2.weight: 0.6780850887298584
# Direction for fc2.bias: 0.039293091744184494
# Epoch 55, Batch 0:
# Direction for fc1.weight: 2.4096004962921143
# Direction for fc1.bias: 0.44779089093208313
# Direction for fc2.weight: 0.6725385785102844
# Direction for fc2.bias: 0.03313320130109787
# Epoch 56, Batch 0:
# Direction for fc1.weight: 2.2248427867889404
# Direction for fc1.bias: 0.3451698124408722
# Direction for fc2.weight: 0.6682471036911011
# Direction for fc2.bias: 0.03504185751080513
# Epoch 57, Batch 0:
# Direction for fc1.weight: 2.345743417739868
# Direction for fc1.bias: 0.42217668890953064
# Direction for fc2.weight: 0.6617493629455566
# Direction for fc2.bias: 0.03512885421514511
# Epoch 58, Batch 0:
# Direction for fc1.weight: 2.232621669769287
# Direction for fc1.bias: 0.49536845088005066
# Direction for fc2.weight: 0.6557046175003052
# Direction for fc2.bias: 0.03436316177248955
# Epoch 59, Batch 0:
# Direction for fc1.weight: 2.495694398880005
# Direction for fc1.bias: 0.34638938307762146
# Direction for fc2.weight: 0.649112343788147
# Direction for fc2.bias: 0.03397888317704201
# Epoch 60, Batch 0:
# Direction for fc1.weight: 2.194075107574463
# Direction for fc1.bias: 0.4983406364917755
# Direction for fc2.weight: 0.6430587768554688
# Direction for fc2.bias: 0.02870011515915394
# Epoch 60, Loss: 1.7806587219238281
# Epoch 61, Batch 0:
# Direction for fc1.weight: 2.294306993484497
# Direction for fc1.bias: 0.43067339062690735
# Direction for fc2.weight: 0.63629549741745
# Direction for fc2.bias: 0.02892214059829712
# Epoch 62, Batch 0:
# Direction for fc1.weight: 2.244158983230591
# Direction for fc1.bias: 0.4205387532711029
# Direction for fc2.weight: 0.6317577362060547
# Direction for fc2.bias: 0.030593551695346832
# Epoch 63, Batch 0:
# Direction for fc1.weight: 2.452562093734741
# Direction for fc1.bias: 0.4715050756931305
# Direction for fc2.weight: 0.6238825917243958
# Direction for fc2.bias: 0.03153756260871887
# Epoch 64, Batch 0:
# Direction for fc1.weight: 2.2214162349700928
# Direction for fc1.bias: 0.4470047950744629
# Direction for fc2.weight: 0.6168572902679443
# Direction for fc2.bias: 0.027961350977420807
# Epoch 65, Batch 0:
# Direction for fc1.weight: 2.110809564590454
# Direction for fc1.bias: 0.4814283847808838
# Direction for fc2.weight: 0.6103548407554626
# Direction for fc2.bias: 0.029234251007437706
# Epoch 66, Batch 0:
# Direction for fc1.weight: 2.0102956295013428
# Direction for fc1.bias: 0.43998223543167114
# Direction for fc2.weight: 0.6042807698249817
# Direction for fc2.bias: 0.02922341227531433
# Epoch 67, Batch 0:
# Direction for fc1.weight: 2.4796414375305176
# Direction for fc1.bias: 0.42959681153297424
# Direction for fc2.weight: 0.5961692333221436
# Direction for fc2.bias: 0.026567799970507622
# Epoch 68, Batch 0:
# Direction for fc1.weight: 2.1331396102905273
# Direction for fc1.bias: 0.49137669801712036
# Direction for fc2.weight: 0.5931976437568665
# Direction for fc2.bias: 0.023341218009591103
# Epoch 69, Batch 0:
# Direction for fc1.weight: 2.1962146759033203
# Direction for fc1.bias: 0.4439302980899811
# Direction for fc2.weight: 0.5875956416130066
# Direction for fc2.bias: 0.023875778540968895
# Epoch 70, Batch 0:
# Direction for fc1.weight: 2.383307695388794
# Direction for fc1.bias: 0.54886394739151
# Direction for fc2.weight: 0.5811271667480469
# Direction for fc2.bias: 0.026174722239375114
# Epoch 70, Loss: 1.7638472318649292
# Epoch 71, Batch 0:
# Direction for fc1.weight: 2.013261318206787
# Direction for fc1.bias: 0.4338044822216034
# Direction for fc2.weight: 0.5791565775871277
# Direction for fc2.bias: 0.022534357383847237
# Epoch 72, Batch 0:
# Direction for fc1.weight: 2.213402509689331
# Direction for fc1.bias: 0.4301901161670685
# Direction for fc2.weight: 0.5756672620773315
# Direction for fc2.bias: 0.02330210991203785
# Epoch 73, Batch 0:
# Direction for fc1.weight: 2.3649401664733887
# Direction for fc1.bias: 0.5273023247718811
# Direction for fc2.weight: 0.5692098140716553
# Direction for fc2.bias: 0.02539145201444626
# Epoch 74, Batch 0:
# Direction for fc1.weight: 2.2010281085968018
# Direction for fc1.bias: 0.4078902304172516
# Direction for fc2.weight: 0.5693122744560242
# Direction for fc2.bias: 0.020737335085868835
# Epoch 75, Batch 0:
# Direction for fc1.weight: 2.229433536529541
# Direction for fc1.bias: 0.4478629529476166
# Direction for fc2.weight: 0.5651166439056396
# Direction for fc2.bias: 0.022542297840118408
# Epoch 76, Batch 0:
# Direction for fc1.weight: 2.209951639175415
# Direction for fc1.bias: 0.4415907561779022
# Direction for fc2.weight: 0.5627245903015137
# Direction for fc2.bias: 0.018225649371743202
# Epoch 77, Batch 0:
# Direction for fc1.weight: 2.2084107398986816
# Direction for fc1.bias: 0.4291467070579529
# Direction for fc2.weight: 0.5608762502670288
# Direction for fc2.bias: 0.022729450836777687
# Epoch 78, Batch 0:
# Direction for fc1.weight: 2.1428282260894775
# Direction for fc1.bias: 0.5043852925300598
# Direction for fc2.weight: 0.556993842124939
# Direction for fc2.bias: 0.0189121812582016
# Epoch 79, Batch 0:
# Direction for fc1.weight: 1.9936646223068237
# Direction for fc1.bias: 0.4044768214225769
# Direction for fc2.weight: 0.5551924109458923
# Direction for fc2.bias: 0.021113788709044456
# Epoch 80, Batch 0:
# Direction for fc1.weight: 2.4141476154327393
# Direction for fc1.bias: 0.4331780672073364
# Direction for fc2.weight: 0.5502508878707886
# Direction for fc2.bias: 0.022279739379882812
# Epoch 80, Loss: 1.74418306350708
# Epoch 81, Batch 0:
# Direction for fc1.weight: 2.1659252643585205
# Direction for fc1.bias: 0.4268549978733063
# Direction for fc2.weight: 0.5535457134246826
# Direction for fc2.bias: 0.019221430644392967
# Epoch 82, Batch 0:
# Direction for fc1.weight: 2.1233420372009277
# Direction for fc1.bias: 0.4901556074619293
# Direction for fc2.weight: 0.5503673553466797
# Direction for fc2.bias: 0.016104701906442642
# Epoch 83, Batch 0:
# Direction for fc1.weight: 2.230733871459961
# Direction for fc1.bias: 0.3457798957824707
# Direction for fc2.weight: 0.5505116581916809
# Direction for fc2.bias: 0.02039945125579834
# Epoch 84, Batch 0:
# Direction for fc1.weight: 2.111743688583374
# Direction for fc1.bias: 0.49685347080230713
# Direction for fc2.weight: 0.5503422021865845
# Direction for fc2.bias: 0.017988407984375954
# Epoch 85, Batch 0:
# Direction for fc1.weight: 2.2724831104278564
# Direction for fc1.bias: 0.4816075265407562
# Direction for fc2.weight: 0.5479404330253601
# Direction for fc2.bias: 0.020550362765789032
# Epoch 86, Batch 0:
# Direction for fc1.weight: 2.1774914264678955
# Direction for fc1.bias: 0.4314627945423126
# Direction for fc2.weight: 0.5500207543373108
# Direction for fc2.bias: 0.018604399636387825
# Epoch 87, Batch 0:
# Direction for fc1.weight: 2.24550199508667
# Direction for fc1.bias: 0.49992266297340393
# Direction for fc2.weight: 0.546973705291748
# Direction for fc2.bias: 0.022701967507600784
# Epoch 88, Batch 0:
# Direction for fc1.weight: 2.3181939125061035
# Direction for fc1.bias: 0.4181310534477234
# Direction for fc2.weight: 0.5487170219421387
# Direction for fc2.bias: 0.01986081711947918
# Epoch 89, Batch 0:
# Direction for fc1.weight: 2.0606136322021484
# Direction for fc1.bias: 0.38744449615478516
# Direction for fc2.weight: 0.549035906791687
# Direction for fc2.bias: 0.018167972564697266
# Epoch 90, Batch 0:
# Direction for fc1.weight: 2.220590829849243
# Direction for fc1.bias: 0.4961516857147217
# Direction for fc2.weight: 0.5487194657325745
# Direction for fc2.bias: 0.019568558782339096
# Epoch 90, Loss: 1.7197108268737793
# Epoch 91, Batch 0:
# Direction for fc1.weight: 2.140847682952881
# Direction for fc1.bias: 0.4316365420818329
# Direction for fc2.weight: 0.5495004653930664
# Direction for fc2.bias: 0.017333433032035828
# Epoch 92, Batch 0:
# Direction for fc1.weight: 2.2627780437469482
# Direction for fc1.bias: 0.4291093349456787
# Direction for fc2.weight: 0.546826958656311
# Direction for fc2.bias: 0.02088402397930622
# Epoch 93, Batch 0:
# Direction for fc1.weight: 2.2044928073883057
# Direction for fc1.bias: 0.49986785650253296
# Direction for fc2.weight: 0.5477141737937927
# Direction for fc2.bias: 0.01782129891216755
# Epoch 94, Batch 0:
# Direction for fc1.weight: 2.015266180038452
# Direction for fc1.bias: 0.3925916254520416
# Direction for fc2.weight: 0.5466814637184143
# Direction for fc2.bias: 0.016278333961963654
# Epoch 95, Batch 0:
# Direction for fc1.weight: 2.238910436630249
# Direction for fc1.bias: 0.4503834545612335
# Direction for fc2.weight: 0.5446817278862
# Direction for fc2.bias: 0.01826356165111065
# Epoch 96, Batch 0:
# Direction for fc1.weight: 2.1691036224365234
# Direction for fc1.bias: 0.5043172836303711
# Direction for fc2.weight: 0.5452942252159119
# Direction for fc2.bias: 0.0165786761790514
# Epoch 97, Batch 0:
# Direction for fc1.weight: 2.1111972332000732
# Direction for fc1.bias: 0.48156583309173584
# Direction for fc2.weight: 0.5437005758285522
# Direction for fc2.bias: 0.016561727970838547
# Epoch 98, Batch 0:
# Direction for fc1.weight: 2.225637912750244
# Direction for fc1.bias: 0.4308435618877411
# Direction for fc2.weight: 0.5433929562568665
# Direction for fc2.bias: 0.019601255655288696
# Epoch 99, Batch 0:
# Direction for fc1.weight: 2.031578540802002
# Direction for fc1.bias: 0.513228178024292
# Direction for fc2.weight: 0.5423434376716614
# Direction for fc2.bias: 0.018667055293917656
# Training complete!
