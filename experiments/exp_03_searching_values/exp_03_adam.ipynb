# %% [markdown]
# ### Optimizer: Adam
#
# In this notebook I will attempt to observe the values for the optimal alpha given the quadratic approximation of the loss for a mini batch
# $L(\theta) \approx q(\theta):=\frac{1}{2}\left(\theta-\theta_0\right)^{\top} H\left(\theta-\theta_0\right)+\left(\theta-\theta_0\right)^{\top} \cdot g+c$
#
#
# along a direction d
#
# $h(\alpha)=q\left(\theta_0+\alpha \cdot d\right)$
#
#
# which is
# $\alpha^*=\frac{-d^{\top} g}{d^{\top} H d}$

# %% [markdown]
# First we define a simple model:

# %%
import torch
from torch import rand
import torch.nn as nn
import torch.optim as optim
from backpack import backpack, extend
from backpack.extensions import (
    GGNMP,
    HMP,
    KFAC,
    KFLR,
    KFRA,
    PCHMP,
    BatchDiagGGNExact,
    BatchDiagGGNMC,
    BatchDiagHessian,
    BatchGrad,
    BatchL2Grad,
    DiagGGNExact,
    DiagGGNMC,
    DiagHessian,
    SqrtGGNExact,
    SqrtGGNMC,
    SumGradSquared,
    Variance,
)
from backpack.utils.examples import load_one_batch_mnist


# Define a simple neural network with nn.ReLU instead of torch.relu
# Define a simple neural network using Sequential
model = nn.Sequential(
    nn.Linear(10, 5),
    nn.ReLU(),  # Use nn.ReLU module directly in Sequential
    nn.Linear(5, 1)
)

# Create a simple dataset
X = torch.randn(1000, 10)
y = torch.randn(1000, 1)


optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# IMPORTANT: extend youre model with backpack, otherwise the parameters will not be extended
# Extend the model and criterion with BackPACK
model = extend(model, use_converter=True) # Extend the loss function
criterion = extend(criterion)

# Training loop
n_epochs = 1
batch_size = 32

# %% [markdown]
# ### Explanation for the Matrix-free multiplication
#
# (1) Anzahl der Parameter: p
# Wir nehmen an, dass das Modell p Paramter hat. Dann hat die Hessematrix die Dimension p x p.
#
#
# (2) Block diagonal Hessian: hmp
# Backpack liefert Matrix freie Multiplikation mit der Block-diagonal Hessian. Das ist eine Version der Hessematrix in der auf
# der Diagonalen Blöcke liegen die berechnet wurden. Die Restlichen Werte sind eigentlich nullen.
# In Backpack sind die restlichen freien Felder nicht existent: Es wird zu jeder Gruppe von Parametern eine Funktion geschrieben, welche
# die Multiplikation mit diesem Block ermöglich.
#
# Diese Multiplikation ist abrufbar über param.hmp(Vektor).
# Dabei kann (muss??) der Vektor auch eine komische Dimension haben:
# Angenommen der aktuelle Block der hmp-matrix hat die dimension 50 x 50. Dann kann der "Vektor" die Dimension 5 x 10 haben (bzw 1 x 5 x 10)
# und dieser wird flattenden (50 x 1) mit dem 50 x 50 Block multipliziert.
#
#  Beispiel:
#
#   Netzwerk: Linear(10, 5),
#             ReLU(),
#             Linear(5, 1)
# )
#
#  Das erste Layer hat *param.shape:              5 x 10 (also 50 params, eigentlich hat der Block der Hessian hier 50 x 50)
#  Wir können nun einen Vektor des shapes 5 x 10 (bzw 1 x 5 x 10, unterschied unklar) damit multiplizieren über
#  param.hmp(v)

# %% [markdown]
# Then we train using Adam and try to observe d from adam:

# %%
# Initialize an empty list to store flattened directions and gradients
d_list = []
g_list = []

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        # Get mini-batch
        X_batch = X[i:i+batch_size]
        y_batch = y[i:i+batch_size]

        # Forward pass
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)

        # Backward pass
        optimizer.zero_grad()  # Reset gradients
        
        # do backward with backpack and get: Hessian (HMP), generalized Gauss-Newton (GGNMP), positive-curvature Hessian (PCHMP)
        # where clip = negative values are set to 0 and abs = set to pos value (I believe)
        with backpack(
            HMP(),
            GGNMP(),
            PCHMP(savefield="pchmp_clip", modify="clip"),
            PCHMP(savefield="pchmp_abs", modify="abs"),
        ):
            loss.backward()
        

        
        V = 1

        loop_count = 0

        
 
        for name, param in model.named_parameters():
            loop_count = loop_count + 1
            if loop_count < 1000:
                # Access parameter name
                print("Parameter Name:", name)

                print("Parameter Dimension:", param.shape)
    
                # Access parameter values
                print("Parameter Values (Tensor):", param)
                vec = rand(V, *param.shape)
                print(name)
                print("*param.shape             ", *param.shape)
                print(".grad.shape:             ", param.grad.shape)
                print("vec.shape:               ", vec.shape)
                print(".hmp(vec).shape:         ", param.hmp(vec).shape)
                print(".ggnmp(vec).shape:       ", param.ggnmp(vec).shape)
                print(".pchmp_clip(vec).shape:  ", param.pchmp_clip(vec).shape)
                print(".pchmp_abs(vec).shape:   ", param.pchmp_abs(vec).shape)

            
            
        # Clear lists for directions and gradients
        d_list.clear()
        g_list.clear()

        for param in model.parameters():
            if param.grad is not None:
                # Flatten and store the gradient for this parameter
                g_list.append(param.grad.view(-1))

                if param not in optimizer.state:
                    # Initialize state if it doesn't exist
                    optimizer.state[param]['exp_avg'] = torch.zeros_like(param.data)
                    optimizer.state[param]['exp_avg_sq'] = torch.zeros_like(param.data)
                    optimizer.state[param]['step'] = torch.tensor(0)  # Initialize as tensor

                # Ensure 'step' is a tensor
                if isinstance(optimizer.state[param]['step'], int):
                    optimizer.state[param]['step'] = torch.tensor(optimizer.state[param]['step'])

                # Get Adam's internal state (first and second moments)
                m_t = optimizer.state[param]['exp_avg']        # First moment (moving average of gradients)
                v_t = optimizer.state[param]['exp_avg_sq']     # Second moment (moving average of squared gradients)

                # Bias correction for moments
                beta1, beta2 = optimizer.defaults['betas']
                optimizer.state[param]['step'] += 1  # Increment step as tensor
                t = optimizer.state[param]['step'].item()  # Convert step tensor to int

                m_t_hat = m_t / (1 - beta1**t)  # Bias-corrected first moment
                v_t_hat = v_t / (1 - beta2**t)  # Bias-corrected second moment

                # Compute the direction
                d_t = -m_t_hat / (torch.sqrt(v_t_hat) + optimizer.defaults['eps'])  # Adam's update direction

                # Flatten the direction d_t and append it to the list
                d_list.append(d_t.view(-1))

        # Concatenate all flattened directions into a single vector of size (1, p)
        d_vector = torch.cat(d_list).view(1, -1)  # Shape (1, p)
        print("d_vector shape:               ", d_vector.shape)

        # Concatenate all flattened gradients into a single vector of size (p, 1)
        g_vector = torch.cat(g_list).view(-1, 1)  # Shape (p, 1)

        # Optimizer step (updates the parameters)
        optimizer.step()

        # Print the direction vector and gradient for the first mini-batch (for demonstration)
        if i == 0:
            print(f"Epoch {epoch}")
            print(f"Direction vector d (norm): {d_vector.norm()}")  # Print norm of the vector
            print(f"First 10 values of d: {d_vector[0, :10]}")  # First 10 values of d
            print(f"Gradient vector g (norm): {g_vector.norm()}")  # Print norm of the gradient vector
            print(f"First 10 values of g: {g_vector[:10]}")  # First 10 values of the gradient

    # Print epoch loss every 10 epochs
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

print("Training complete!")
# Out:
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1441, -0.2765,  0.0555, -0.1091,  0.2671,  0.1135, -0.0795, -0.1714,
#          -0.1754,  0.0497],
#         [ 0.0260,  0.1523,  0.0323, -0.0600,  0.0187,  0.1121, -0.2201,  0.1883,
#           0.0256, -0.2442],
#         [-0.0895, -0.3066,  0.2458,  0.1361, -0.0063, -0.2038, -0.1190,  0.0204,
#          -0.0769, -0.2011],
#         [ 0.1055, -0.1719,  0.0927,  0.0599,  0.0679,  0.1853,  0.0574, -0.2768,
#          -0.2832, -0.0211],
#         [-0.0834,  0.1070,  0.0634, -0.0230,  0.2120, -0.2448, -0.1284,  0.2943,
#           0.0832,  0.1892]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3315,  0.2078, -0.0276, -0.2915, -0.1707], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1136, -0.1173,  0.3130, -0.1298,  0.2731]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0749], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Epoch 0
# Direction vector d (norm): 2.750685691833496
# First 10 values of d: tensor([ 0.3459,  0.3104, -0.0784,  0.6101, -0.4383, -0.2176, -0.2857,  0.0580,
#          0.1299, -0.1645])
# Gradient vector g (norm): 0.6611987352371216
# First 10 values of g: tensor([[ 3.1734e-02],
#         [-3.6511e-02],
#         [-3.5224e-03],
#         [ 1.7324e-05],
#         [ 2.0729e-02],
#         [ 4.8815e-02],
#         [ 5.4279e-03],
#         [-7.1591e-03],
#         [-1.7900e-02],
#         [-4.6233e-02]])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1439, -0.2760,  0.0554, -0.1086,  0.2666,  0.1132, -0.0798, -0.1713,
#          -0.1752,  0.0498],
#         [ 0.0261,  0.1529,  0.0327, -0.0605,  0.0186,  0.1114, -0.2202,  0.1885,
#           0.0257, -0.2437],
#         [-0.0892, -0.3069,  0.2452,  0.1361, -0.0062, -0.2032, -0.1191,  0.0203,
#          -0.0770, -0.2013],
#         [ 0.1054, -0.1717,  0.0927,  0.0603,  0.0677,  0.1847,  0.0575, -0.2766,
#          -0.2832, -0.0207],
#         [-0.0840,  0.1068,  0.0629, -0.0228,  0.2119, -0.2446, -0.1278,  0.2943,
#           0.0830,  0.1889]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3322,  0.2080, -0.0278, -0.2917, -0.1709], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1127, -0.1174,  0.3127, -0.1293,  0.2725]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0752], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1438, -0.2754,  0.0554, -0.1080,  0.2661,  0.1127, -0.0802, -0.1715,
#          -0.1750,  0.0498],
#         [ 0.0263,  0.1536,  0.0331, -0.0607,  0.0184,  0.1105, -0.2202,  0.1885,
#           0.0256, -0.2434],
#         [-0.0889, -0.3073,  0.2447,  0.1360, -0.0059, -0.2025, -0.1189,  0.0202,
#          -0.0770, -0.2014],
#         [ 0.1053, -0.1714,  0.0925,  0.0604,  0.0675,  0.1842,  0.0574, -0.2765,
#          -0.2831, -0.0204],
#         [-0.0846,  0.1065,  0.0623, -0.0226,  0.2120, -0.2444, -0.1271,  0.2945,
#           0.0829,  0.1887]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3331,  0.2082, -0.0280, -0.2920, -0.1710], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1120, -0.1175,  0.3124, -0.1289,  0.2721]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0753], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.
requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1422, -0.2742,  0.0546, -0.1043,  0.2633,  0.1086, -0.0826, -0.1718,
#          -0.1755,  0.0489],
#         [ 0.0280,  0.1551,  0.0359, -0.0637,  0.0196,  0.1048, -0.2222,  0.1909,
#           0.0236, -0.2418],
#         [-0.0880, -0.3069,  0.2416,  0.1357, -0.0042, -0.1970, -0.1168,  0.0205,
#          -0.0766, -0.2006],
#         [ 0.1059, -0.1733,  0.0907,  0.0600,  0.0657,  0.1790,  0.0570, -0.2738,
#          -0.2853, -0.0208],
#         [-0.0889,  0.1062,  0.0601, -0.0202,  0.2124, -0.2414, -0.1236,  0.2947,
#           0.0821,  0.1900]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3373,  0.2083, -0.0308, -0.2931, -0.1708], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1079, -0.1182,  0.3075, -0.1258,  0.2696]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0751], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1422, -0.2743,  0.0544, -0.1039,  0.2632,  0.1082, -0.0827, -0.1717,
#          -0.1755,  0.0487],
#         [ 0.0283,  0.1547,  0.0362, -0.0638,  0.0197,  0.1045, -0.2222,  0.1911,
#           0.0235, -0.2416],
#         [-0.0880, -0.3068,  0.2415,  0.1354, -0.0041, -0.1965, -0.1166,  0.0204,
#          -0.0768, -0.2006],
#         [ 0.1059, -0.1735,  0.0906,  0.0598,  0.0658,  0.1786,  0.0571, -0.2735,
#          -0.2853, -0.0210],
#         [-0.0892,  0.1064,  0.0598, -0.0203,  0.2126, -0.2409, -0.1233,  0.2947,
#           0.0822,  0.1901]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3375,  0.2081, -0.0309, -0.2933, -0.1707], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1076, -0.1179,  0.3071, -0.1255,  0.2695]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0748], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1422, -0.2744,  0.0542, -0.1035,  0.2631,  0.1078, -0.0828, -0.1716,
#          -0.1756,  0.0484],
#         [ 0.0286,  0.1542,  0.0364, -0.0641,  0.0195,  0.1042, -0.2221,  0.1913,
#           0.0235, -0.2416],
#         [-0.0881, -0.3065,  0.2414,  0.1351, -0.0037, -0.1960, -0.1165,  0.0204,
#          -0.0771, -0.2004],
#         [ 0.1058, -0.1736,  0.0904,  0.0597,  0.0658,  0.1782,  0.0572, -0.2733,
#          -0.2853, -0.0213],
#         [-0.0895,  0.1068,  0.0597, -0.0204,  0.2127, -0.2405, -0.1231,  0.2947,
#           0.0821,  0.1903]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3377,  0.2080, -0.0311, -0.2935, -0.1706], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1074, -0.1177,  0.3065, -0.1252,  0.2694]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0746], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1422, -0.2746,  0.0541, -0.1032,  0.2631,  0.1076, -0.0830, -0.1715,
#          -0.1755,  0.0482],
#         [ 0.0289,  0.1537,  0.0364, -0.0645,  0.0196,  0.1040, -0.2221,  0.1917,
#           0.0234, -0.2416],
#         [-0.0882, -0.3062,  0.2415,  0.1349, -0.0034, -0.1957, -0.1163,  0.0202,
#          -0.0774, -0.2003],
#         [ 0.1060, -0.1737,  0.0902,  0.0597,  0.0660,  0.1778,  0.0572, -0.2733,
#          -0.2853, -0.0214],
#         [-0.0897,  0.1072,  0.0598, -0.0203,  0.2127, -0.2403, -0.1229,  0.2944,
#           0.0821,  0.1906]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3378,  0.2080, -0.0312, -0.2935, -0.1707], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1074, -0.1176,  0.3062, -0.1251,  0.2693]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0745], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1423, -0.2747,  0.0537, -0.1028,  0.2631,  0.1073, -0.0831, -0.1714,
#          -0.1754,  0.0479],
#         [ 0.0290,  0.1533,  0.0363, -0.0649,  0.0196,  0.1037, -0.2219,  0.1921,
#           0.0235, -0.2415],
#         [-0.0881, -0.3060,  0.2416,  0.1350, -0.0033, -0.1951, -0.1164,  0.0200,
#          -0.0777, -0.2002],
#         [ 0.1060, -0.1737,  0.0897,  0.0596,  0.0662,  0.1773,  0.0574, -0.2733,
#          -0.2853, -0.0215],
#         [-0.0899,  0.1075,  0.0598, -0.0202,  0.2124, -0.2401, -0.1228,  0.2940,
#           0.0820,  0.1909]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3380,  0.2082, -0.0313, -0.2936, -0.1709], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1072, -0.1175,  0.3059, -0.1247,  0.2691]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0745], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1425, -0.2748,  0.0533, -0.1025,  0.2633,  0.1069, -0.0832, -0.1713,
#          -0.1753,  0.0477],
#         [ 0.0288,  0.1529,  0.0360, -0.0652,  0.0196,  0.1034, -0.2219,  0.1923,
#           0.0238, -0.2416],
#         [-0.0879, -0.3058,  0.2418,  0.1350, -0.0032, -0.1946, -0.1164,  0.0199,
#          -0.0780, -0.1999],
#         [ 0.1059, -0.1736,  0.0893,  0.0596,  0.0665,  0.1769,  0.0575, -0.2732,
#          -0.2853, -0.0216],
#         [-0.0898,  0.1079,  0.0599, -0.0202,  0.2121, -0.2400, -0.1228,  0.2937,
#           0.0820,  0.1911]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3382,  0.2082, -0.0314, -0.2937, -0.1712], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1071, -0.1174,  0.3056, -0.1243,  0.2689]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0744], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1427, -0.2749,  0.0529, -0.1021,  0.2634,  0.1067, -0.0833, -0.1713,
#          -0.1751,  0.0474],
#         [ 0.0286,  0.1526,  0.0356, -0.0654,  0.0196,  0.1029, -0.2220,  0.1924,
#           0.0240, -0.2418],
#         [-0.0877, -0.3057,  0.2422,  0.1350, -0.0032, -0.1941, -0.1162,  0.0198,
#          -0.0785, -0.1998],
#         [ 0.1058, -0.1735,  0.0888,  0.0596,  0.0667,  0.1764,  0.0574, -0.2732,
#          -0.2852, -0.0218],
#         [-0.0898,  0.1083,  0.0601, -0.0202,  0.2120, -0.2398, -0.1227,  0.2934,
#           0.0819,  0.1909]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3383,  0.2082, -0.0314, -0.2938, -0.1715], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1070, -0.1173,  0.3054, -0.1239,  0.2687]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0743], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1428, -0.2749,  0.0524, -0.1015,  0.2635,  0.1062, -0.0835, -0.1717,
#          -0.1750,  0.0471],
#         [ 0.0285,  0.1525,  0.0352, -0.0654,  0.0196,  0.1025, -0.2219,  0.1924,
#           0.0244, -0.2419],
#         [-0.0876, -0.3056,  0.2426,  0.1347, -0.0031, -0.1935, -0.1160,  0.0201,
#          -0.0787, -0.1995],
#         [ 0.1060, -0.1735,  0.0883,  0.0597,  0.0671,  0.1759,  0.0573, -0.2733,
#          -0.2853, -0.0219],
#         [-0.0898,  0.1085,  0.0603, -0.0203,  0.2121, -0.2399, -0.1226,  0.2931,
#           0.0820,  0.1911]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3383,  0.2081, -0.0313, -0.2938, -0.1715], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1069, -0.1170,  0.3051, -0.1236,  0.2687]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0741], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# ...
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0734], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1429, -0.2737,  0.0495, -0.0991,  0.2643,  0.1032, -0.0849, -0.1718,
#          -0.1745,  0.0448],
#         [ 0.0253,  0.1530,  0.0332, -0.0652,  0.0181,  0.1003, -0.2205,  0.1923,
#           0.0286, -0.2428],
#         [-0.0863, -0.3068,  0.2425,  0.1344, -0.0031, -0.1896, -0.1139,  0.0190,
#          -0.0811, -0.1969],
#         [ 0.1057, -0.1728,  0.0846,  0.0596,  0.0697,  0.1719,  0.0580, -0.2727,
#          -0.2845, -0.0247],
#         [-0.0891,  0.1090,  0.0597, -0.0185,  0.2140, -0.2384, -0.1205,  0.2924,
#           0.0822,  0.1921]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3403,  0.2085, -0.0312, -0.2954, -0.1720], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1051, -0.1164,  0.3029, -0.1204,  0.2677]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0734], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1428, -0.2735,  0.0493, -0.0989,  0.2644,  0.1030, -0.0849, -0.1718,
#          -0.1743,  0.0448],
#         [ 0.0252,  0.1530,  0.0334, -0.0652,  0.0178,  0.1001, -0.2203,  0.1922,
#           0.0292, -0.2429],
#         [-0.0864, -0.3069,  0.2421,  0.1343, -0.0027, -0.1891, -0.1137,  0.0190,
#          -0.0815, -0.1967],
#         [ 0.1057, -0.1727,  0.0845,  0.0596,  0.0699,  0.1715,  0.0582, -0.2727,
#          -0.2843, -0.0249],
#         [-0.0891,  0.1091,  0.0595, -0.0184,  0.2143, -0.2384, -0.1203,  0.2923,
#           0.0821,  0.1921]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3406,  0.2083, -0.0311, -0.2955, -0.1718], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1048, -0.1163,  0.3025, -0.1201,  0.2676]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0733], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1428, -0.2733,  0.0492, -0.0988,  0.2644,  0.1027, -0.0849, -0.1717,
#          -0.1742,  0.0447],
#         [ 0.0252,  0.1532,  0.0338, -0.0653,  0.0175,  0.0999, -0.2202,  0.1923,
#           0.0297, -0.2431],
#         [-0.0864, -0.3071,  0.2415,  0.1342, -0.0022, -0.1886, -0.1136,  0.0187,
#          -0.0814, -0.1966],
#         [ 0.1057, -0.1726,  0.0845,  0.0595,  0.0700,  0.1711,  0.0585, -0.2726,
#          -0.2842, -0.0250],
#         [-0.0891,  0.1091,  0.0590, -0.0183,  0.2144, -0.2384, -0.1200,  0.2922,
#           0.0821,  0.1920]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3407,  0.2084, -0.0313, -0.2956, -0.1719], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1045, -0.1164,  0.3020, -0.1198,  0.2672]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0734], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1428, -0.2731,  0.0491, -0.0987,  0.2644,  0.1025, -0.0849, -0.1715,
#          -0.1742,  0.0448],
#         [ 0.0252,  0.1532,  0.0342, -0.0656,  0.0172,  0.0996, -0.2201,  0.1924,
#           0.0299, -0.2429],
#         [-0.0864, -0.3071,  0.2410,  0.1343, -0.0017, -0.1881, -0.1135,  0.0184,
#          -0.0812, -0.1966],
#         [ 0.1059, -0.1726,  0.0845,  0.0595,  0.0701,  0.1707,  0.0588, -0.2724,
#          -0.2842, -0.0250],
#         [-0.0891,  0.1093,  0.0586, -0.0180,  0.2146, -0.2384, -0.1198,  0.2921,
#           0.0823,  0.1918]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3409,  0.2083, -0.0314, -0.2957, -0.1717], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1042, -0.1163,  0.3016, -0.1196,  0.2671]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0734], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1429, -0.2730,  0.0489, -0.0985,  0.2643,  0.1022, -0.0849, -0.1713,
#          -0.1741,  0.0449],
#         [ 0.0253,  0.1532,  0.0345, -0.0659,  0.0169,  0.0993, -0.2199,  0.1927,
#           0.0301, -0.2427],
#         [-0.0864, -0.3071,  0.2406,  0.1346, -0.0014, -0.1877, -0.1135,  0.0181,
#          -0.0811, -0.1967],
#         [ 0.1060, -0.1725,  0.0844,  0.0597,  0.0701,  0.1703,  0.0590, -0.2721,
#          -0.2842, -0.0249],
#         [-0.0893,  0.1094,  0.0582, -0.0177,  0.2147, -0.2386, -0.1198,  0.2919,
#           0.0826,  0.1917]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3411,  0.2082, -0.0314, -0.2959, -0.1716], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1038, -0.1161,  0.3012, -0.1192,  0.2669]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0734], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Parameter Name: 0.weight
# Parameter Dimension: torch.Size([5, 10])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1430, -0.2727,  0.0487, -0.0982,  0.2642,  0.1019, -0.0849, -0.1711,
#          -0.1741,  0.0451],
#         [ 0.0255,  0.1532,  0.0347, -0.0661,  0.0165,  0.0990, -0.2195,  0.1932,
#           0.0303, -0.2424],
#         [-0.0862, -0.3070,  0.2401,  0.1348, -0.0011, -0.1873, -0.1137,  0.0179,
#          -0.0808, -0.1968],
#         [ 0.1062, -0.1725,  0.0844,  0.0599,  0.0702,  0.1699,  0.0591, -0.2719,
#          -0.2843, -0.0248],
#         [-0.0898,  0.1095,  0.0579, -0.0174,  0.2150, -0.2386, -0.1198,  0.2915,
#           0.0829,  0.1914]], requires_grad=True)
# 0.weight
# *param.shape              5 10
# .grad.shape:              torch.Size([5, 10])
# vec.shape:                torch.Size([1, 5, 10])
# .hmp(vec).shape:          torch.Size([1, 5, 10])
# .ggnmp(vec).shape:        torch.Size([1, 5, 10])
# .pchmp_clip(vec).shape:   torch.Size([1, 5, 10])
# .pchmp_abs(vec).shape:    torch.Size([1, 5, 10])
# Parameter Name: 0.bias
# Parameter Dimension: torch.Size([5])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.3413,  0.2083, -0.0314, -0.2960, -0.1717], requires_grad=True)
# 0.bias
# *param.shape              5
# .grad.shape:              torch.Size([5])
# vec.shape:                torch.Size([1, 5])
# .hmp(vec).shape:          torch.Size([1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 5])
# Parameter Name: 2.weight
# Parameter Dimension: torch.Size([1, 5])
# Parameter Values (Tensor): Parameter containing:
# tensor([[-0.1034, -0.1161,  0.3008, -0.1190,  0.2668]], requires_grad=True)
# 2.weight
# *param.shape              1 5
# .grad.shape:              torch.Size([1, 5])
# vec.shape:                torch.Size([1, 1, 5])
# .hmp(vec).shape:          torch.Size([1, 1, 5])
# .ggnmp(vec).shape:        torch.Size([1, 1, 5])
# .pchmp_clip(vec).shape:   torch.Size([1, 1, 5])
# .pchmp_abs(vec).shape:    torch.Size([1, 1, 5])
# Parameter Name: 2.bias
# Parameter Dimension: torch.Size([1])
# Parameter Values (Tensor): Parameter containing:
# tensor([-0.0736], requires_grad=True)
# 2.bias
# *param.shape              1
# .grad.shape:              torch.Size([1])
# vec.shape:                torch.Size([1, 1])
# .hmp(vec).shape:          torch.Size([1, 1])
# .ggnmp(vec).shape:        torch.Size([1, 1])
# .pchmp_clip(vec).shape:   torch.Size([1, 1])
# .pchmp_abs(vec).shape:    torch.Size([1, 1])
# d_vector shape:                torch.Size([1, 61])
# Epoch 0, Loss: 1.6887725591659546
# Training complete!
