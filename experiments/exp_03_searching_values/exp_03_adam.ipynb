# %% [markdown]
# ### Optimizer: Adam
#
# In this notebook I will attempt to observe the values for the optimal alpha given the quadratic approximation of the loss for a mini batch
# $L(\theta) \approx q(\theta):=\frac{1}{2}\left(\theta-\theta_0\right)^{\top} H\left(\theta-\theta_0\right)+\left(\theta-\theta_0\right)^{\top} \cdot g+c$
#
#
# along a direction d
#
# $h(\alpha)=q\left(\theta_0+\alpha \cdot d\right)$
#
#
# which is
# $\alpha^*=\frac{-d^{\top} g}{d^{\top} H d}$

# %% [markdown]
# First we define a simple model:

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define a simple neural network
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(10, 5)
        self.fc2 = nn.Linear(5, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Create a simple dataset
X = torch.randn(1000, 10)
y = torch.randn(1000, 1)

# Initialize the model and optimizer
model = SimpleNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.MSELoss()

# Training loop
n_epochs = 100
batch_size = 32

# %% [markdown]
# Then we train using Adam and try to observe d from adam:

# %%
# Initialize an empty list to store flattened directions and gradients
d_list = []
g_list = []

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        # Get mini-batch
        X_batch = X[i:i+batch_size]
        y_batch = y[i:i+batch_size]

        # Forward pass
        y_pred = model(X_batch)
        loss = criterion(y_pred, y_batch)

        # Backward pass
        optimizer.zero_grad()  # Reset gradients
        loss.backward()  # Compute gradients

        # Clear lists for directions and gradients
        d_list.clear()
        g_list.clear()

        for param in model.parameters():
            if param.grad is not None:
                # Flatten and store the gradient for this parameter
                g_list.append(param.grad.view(-1))

                if param not in optimizer.state:
                    # Initialize state if it doesn't exist
                    optimizer.state[param]['exp_avg'] = torch.zeros_like(param.data)
                    optimizer.state[param]['exp_avg_sq'] = torch.zeros_like(param.data)
                    optimizer.state[param]['step'] = torch.tensor(0)  # Initialize as tensor

                # Ensure 'step' is a tensor
                if isinstance(optimizer.state[param]['step'], int):
                    optimizer.state[param]['step'] = torch.tensor(optimizer.state[param]['step'])

                # Get Adam's internal state (first and second moments)
                m_t = optimizer.state[param]['exp_avg']        # First moment (moving average of gradients)
                v_t = optimizer.state[param]['exp_avg_sq']     # Second moment (moving average of squared gradients)

                # Bias correction for moments
                beta1, beta2 = optimizer.defaults['betas']
                optimizer.state[param]['step'] += 1  # Increment step as tensor
                t = optimizer.state[param]['step'].item()  # Convert step tensor to int

                m_t_hat = m_t / (1 - beta1**t)  # Bias-corrected first moment
                v_t_hat = v_t / (1 - beta2**t)  # Bias-corrected second moment

                # Compute the direction
                d_t = -m_t_hat / (torch.sqrt(v_t_hat) + optimizer.defaults['eps'])  # Adam's update direction

                # Flatten the direction d_t and append it to the list
                d_list.append(d_t.view(-1))

        # Concatenate all flattened directions into a single vector of size (1, p)
        d_vector = torch.cat(d_list).view(1, -1)  # Shape (1, p)

        # Concatenate all flattened gradients into a single vector of size (p, 1)
        g_vector = torch.cat(g_list).view(-1, 1)  # Shape (p, 1)

        # Optimizer step (updates the parameters)
        optimizer.step()

        # Print the direction vector and gradient for the first mini-batch (for demonstration)
        if i == 0:
            print(f"Epoch {epoch}, Batch 0:")
            print(f"Direction vector d (norm): {d_vector.norm()}")  # Print norm of the vector
            print(f"First 10 values of d: {d_vector[0, :10]}")  # First 10 values of d
            print(f"Gradient vector g (norm): {g_vector.norm()}")  # Print norm of the gradient vector
            print(f"First 10 values of g: {g_vector[:10]}")  # First 10 values of the gradient

    # Print epoch loss every 10 epochs
    if epoch % 10 == 0:
        print(f"Epoch {epoch}, Loss: {loss.item()}")

print("Training complete!")
# Out:
# Epoch 0, Batch 0:
# Direction vector d (norm): 1.389596939086914
# First 10 values of d: tensor([ 0.1085,  0.3498,  0.1337,  0.2082,  0.0716, -0.0683,  0.1831, -0.2486,
#         -0.0767,  0.0833])
# Gradient vector g (norm): 1.140217661857605
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1747],
#         [-0.0589],
#         [ 0.0860],
#         [-0.0356],
#         [-0.0953],
#         [ 0.0052],
#         [-0.0552],
#         [ 0.1047],
#         [-0.0160]])
# Epoch 0, Loss: 0.4204362630844116
# Epoch 1, Batch 0:
# Direction vector d (norm): 1.399430751800537
# First 10 values of d: tensor([ 0.1054,  0.3331,  0.1077,  0.2249,  0.0634, -0.0377,  0.1939, -0.2573,
#         -0.1060,  0.0826])
# Gradient vector g (norm): 1.1469032764434814
# First 10 values of g: tensor([[ 0.0350],
#         [ 0.1748],
#         [-0.0589],
#         [ 0.0863],
#         [-0.0356],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0552],
#         [ 0.1047],
#         [-0.0160]])
# Epoch 2, Batch 0:
# Direction vector d (norm): 1.397036075592041
# First 10 values of d: tensor([ 0.0719,  0.3319,  0.1552,  0.2045,  0.0534, -0.0536,  0.1439, -0.2634,
#         -0.1724,  0.1118])
# Gradient vector g (norm): 1.1417732238769531
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1749],
#         [-0.0590],
#         [ 0.0863],
#         [-0.0357],
#         [-0.0956],
#         [ 0.0049],
#         [-0.0554],
#         [ 0.1047],
#         [-0.0160]])
# Epoch 3, Batch 0:
# Direction vector d (norm): 1.4159563779830933
# First 10 values of d: tensor([ 0.0647,  0.2753,  0.1121,  0.2161,  0.0656, -0.0971,  0.3833, -0.1565,
#          0.0090,  0.1561])
# Gradient vector g (norm): 1.1424962282180786
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1749],
#         [-0.0591],
#         [ 0.0865],
#         [-0.0357],
#         [-0.0955],
#         [ 0.0050],
#         [-0.0554],
#         [ 0.1046],
#         [-0.0160]])
# Epoch 4, Batch 0:
# Direction vector d (norm): 1.409695029258728
# First 10 values of d: tensor([ 0.0854,  0.3360,  0.1645,  0.2067,  0.0573, -0.0555,  0.1425, -0.2624,
#         -0.1728,  0.1112])
# Gradient vector g (norm): 1.1407181024551392
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1746],
#         [-0.0589],
#         [ 0.0864],
#         [-0.0356],
#         [-0.0953],
#         [ 0.0053],
#         [-0.0551],
#         [ 0.1047],
#         [-0.0159]])
# Epoch 5, Batch 0:
# Direction vector d (norm): 1.4025955200195312
# First 10 values of d: tensor([ 0.0998,  0.3353,  0.1498,  0.1984,  0.0847, -0.0726,  0.1097, -0.2529,
#         -0.1128,  0.1114])
# Gradient vector g (norm): 1.1412512063980103
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1747],
#         [-0.0589],
#         [ 0.0863],
#         [-0.0356],
#         [-0.0954],
#         [ 0.0052],
#         [-0.0553],
#         [ 0.1047],
#         [-0.0159]])
# Epoch 6, Batch 0:
# Direction vector d (norm): 1.3911956548690796
# First 10 values of d: tensor([ 0.1027,  0.3343,  0.1062,  0.2205,  0.0624, -0.0353,  0.1938, -0.2589,
#         -0.1106,  0.0783])
# Gradient vector g (norm): 1.1417382955551147
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1748],
#         [-0.0590],
#         [ 0.0864],
#         [-0.0358],
#         [-0.0955],
#         [ 0.0051],
#         [-0.0553],
#         [ 0.1046],
#         [-0.0160]])
# Epoch 7, Batch 0:
# Direction vector d (norm): 1.411171555519104
# First 10 values of d: tensor([ 0.1048,  0.3329,  0.1056,  0.2270,  0.0627, -0.0354,  0.1959, -0.2567,
#         -0.1069,  0.0813])
# Gradient vector g (norm): 1.1417324542999268
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1749],
#         [-0.0590],
#         [ 0.0863],
#         [-0.0358],
#         [-0.0954],
#         [ 0.0050],
#         [-0.0554],
#         [ 0.1046],
#         [-0.0161]])
# Epoch 8, Batch 0:
# Direction vector d (norm): 1.3866546154022217
# First 10 values of d: tensor([ 0.1119,  0.3188,  0.0921,  0.2201,  0.0830, -0.0569,  0.2000, -0.2487,
#         -0.1157,  0.0854])
# Gradient vector g (norm): 1.1476643085479736
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1748],
#         [-0.0591],
#         [ 0.0866],
#         [-0.0358],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0554],
#         [ 0.1046],
#         [-0.0160]])
# Epoch 9, Batch 0:
# Direction vector d (norm): 1.4226723909378052
# First 10 values of d: tensor([ 0.0844,  0.3571,  0.1896,  0.1887,  0.0611, -0.0920,  0.1292, -0.2544,
#         -0.1395,  0.1103])
# Gradient vector g (norm): 1.1423755884170532
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1749],
#         [-0.0591],
#         [ 0.0867],
#         [-0.0359],
#         [-0.0953],
#         [ 0.0052],
#         [-0.0553],
#         [ 0.1045],
#         [-0.0162]])
# Epoch 10, Batch 0:
# Direction vector d (norm): 1.4137109518051147
# First 10 values of d: tensor([ 0.0438,  0.2808,  0.1192,  0.2222,  0.0442, -0.0733,  0.3814, -0.1617,
#          0.0243,  0.1579])
# Gradient vector g (norm): 1.1438090801239014
# First 10 values of g: tensor([[ 0.0350],
#         [ 0.1750],
#         [-0.0593],
#         [ 0.0867],
#         [-0.0360],
#         [-0.0953],
#         [ 0.0050],
#         [-0.0554],
#         [ 0.1044],
#         [-0.0162]])
# Epoch 10, Loss: 0.42023563385009766
# Epoch 11, Batch 0:
# Direction vector d (norm): 1.4116814136505127
# First 10 values of d: tensor([ 0.0816,  0.3360,  0.1612,  0.2029,  0.0566, -0.0532,  0.1447, -0.2649,
#         -0.1749,  0.1073])
# Gradient vector g (norm): 1.1434454917907715
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1749],
#         [-0.0592],
#         [ 0.0869],
#         [-0.0361],
#         [-0.0952],
#         [ 0.0054],
#         [-0.0553],
#         [ 0.1044],
#         [-0.0163]])
# Epoch 12, Batch 0:
# Direction vector d (norm): 1.3952116966247559
# First 10 values of d: tensor([ 0.0939,  0.3157,  0.1210,  0.2173,  0.0780, -0.0392,  0.1221, -0.2620,
#         -0.1447,  0.1098])
# Gradient vector g (norm): 1.149634599685669
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1751],
#         [-0.0593],
#         [ 0.0868],
#         [-0.0360],
#         [-0.0955],
#         [ 0.0051],
#         [-0.0555],
#         [ 0.1044],
#         [-0.0162]])
# Epoch 13, Batch 0:
# Direction vector d (norm): 1.4270784854888916
# First 10 values of d: tensor([ 0.0511,  0.2962,  0.1561,  0.2050,  0.0461, -0.1105,  0.3952, -0.1624,
#         -0.0210,  0.1562])
# Gradient vector g (norm): 1.144594669342041
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1752],
#         [-0.0594],
#         [ 0.0871],
#         [-0.0362],
#         [-0.0955],
#         [ 0.0051],
#         [-0.0555],
#         [ 0.1042],
#         [-0.0163]])
# Epoch 14, Batch 0:
# Direction vector d (norm): 1.3982855081558228
# First 10 values of d: tensor([ 0.0966,  0.3333,  0.1517,  0.1983,  0.0858, -0.0734,  0.1173, -0.2512,
#         -0.1057,  0.1148])
# Gradient vector g (norm): 1.1442317962646484
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1751],
#         [-0.0593],
#         [ 0.0870],
#         [-0.0362],
#         [-0.0953],
#         [ 0.0054],
#         [-0.0554],
#         [ 0.1044],
#         [-0.0163]])
# Epoch 15, Batch 0:
# Direction vector d (norm): 1.3975704908370972
# First 10 values of d: tensor([ 0.0780,  0.3381,  0.1609,  0.2049,  0.0540, -0.0589,  0.1386, -0.2661,
#         -0.1757,  0.1043])
# Gradient vector g (norm): 1.149821400642395
# First 10 values of g: tensor([[ 0.0349],
#         [ 0.1753],
#         [-0.0594],
#         [ 0.0870],
#         [-0.0364],
#         [-0.0953],
#         [ 0.0053],
#         [-0.0556],
#         [ 0.1042],
#         [-0.0164]])
# Epoch 16, Batch 0:
# Direction vector d (norm): 1.3864281177520752
# First 10 values of d: tensor([ 0.1097,  0.3096,  0.0623,  0.2351,  0.0853, -0.0229,  0.1791, -0.2539,
#         -0.0750,  0.0821])
# Gradient vector g (norm): 1.1453254222869873
# First 10 values of g: tensor([[ 0.0350],
#         [ 0.1753],
#         [-0.0595],
#         [ 0.0873],
#         [-0.0364],
#         [-0.0952],
#         [ 0.0052],
#         [-0.0556],
#         [ 0.1041],
#         [-0.0164]])
# Epoch 17, Batch 0:
# Direction vector d (norm): 1.4129570722579956
# First 10 values of d: tensor([ 0.0851,  0.3526,  0.2025,  0.2020,  0.0600, -0.0914,  0.1351, -0.2240,
#         -0.1398,  0.1157])
# Gradient vector g (norm): 1.1593925952911377
# First 10 values of g: tensor([[ 0.0350],
#         [ 0.1755],
#         [-0.0596],
#         [ 0.0873],
#         [-0.0366],
#         [-0.0953],
#         [ 0.0051],
#         [-0.0556],
#         [ 0.1040],
#         [-0.0166]])
# Epoch 18, Batch 0:
# Direction vector d (norm): 1.4386485815048218
# First 10 values of d: tensor([ 0.0443,  0.3062,  0.1672,  0.2150,  0.0268, -0.0940,  0.3889, -0.1721,
#         -0.0068,  0.1594])
# Gradient vector g (norm): 1.1646358966827393
# First 10 values of g: tensor([[ 0.0350],
#         [ 0.1755],
#         [-0.0595],
#         [ 0.0875],
#         [-0.0366],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0555],
#         [ 0.1040],
#         [-0.0165]])
# Epoch 19, Batch 0:
# Direction vector d (norm): 1.3791717290878296
# First 10 values of d: tensor([ 0.0894,  0.3113,  0.1143,  0.2135,  0.0769, -0.0423,  0.1313, -0.2633,
#         -0.1413,  0.1093])
# Gradient vector g (norm): 1.158346176147461
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1752],
#         [-0.0596],
#         [ 0.0876],
#         [-0.0367],
#         [-0.0952],
#         [ 0.0053],
#         [-0.0557],
#         [ 0.1040],
#         [-0.0165]])
# Epoch 20, Batch 0:
# Direction vector d (norm): 1.4233254194259644
# First 10 values of d: tensor([ 0.1084,  0.3452,  0.1296,  0.2069,  0.0777, -0.0635,  0.1784, -0.2510,
#         -0.0763,  0.0842])
# Gradient vector g (norm): 1.1579642295837402
# First 10 values of g: tensor([[ 0.0347],
#         [ 0.1752],
#         [-0.0594],
#         [ 0.0876],
#         [-0.0366],
#         [-0.0952],
#         [ 0.0053],
#         [-0.0555],
#         [ 0.1040],
#         [-0.0165]])
# Epoch 20, Loss: 0.4183838963508606
# Epoch 21, Batch 0:
# Direction vector d (norm): 1.3922556638717651
# First 10 values of d: tensor([ 0.0920,  0.3181,  0.1395,  0.2048,  0.0794, -0.0768,  0.1423, -0.2602,
#         -0.1826,  0.1142])
# Gradient vector g (norm): 1.1589610576629639
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1754],
#         [-0.0595],
#         [ 0.0877],
#         [-0.0366],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0557],
#         [ 0.1039],
#         [-0.0164]])
# Epoch 22, Batch 0:
# Direction vector d (norm): 1.4264934062957764
# First 10 values of d: tensor([ 0.0518,  0.2861,  0.1259,  0.2197,  0.0478, -0.0784,  0.3801, -0.1682,
#          0.0231,  0.1544])
# Gradient vector g (norm): 1.1592915058135986
# First 10 values of g: tensor([[ 0.0348],
#         [ 0.1754],
#         [-0.0596],
#         [ 0.0879],
#         [-0.0367],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0556],
#         [ 0.1038],
#         [-0.0165]])
# Epoch 23, Batch 0:
# Direction vector d (norm): 1.410192608833313
# First 10 values of d: tensor([ 0.0824,  0.3340,  0.1620,  0.2092,  0.0578, -0.0550,  0.1440, -0.2658,
#         -0.1688,  0.1113])
# Gradient vector g (norm): 1.1636124849319458
# First 10 values of g: tensor([[ 0.0346],
#         [ 0.1752],
#         [-0.0594],
#         [ 0.0878],
#         [-0.0364],
#         [-0.0954],
#         [ 0.0053],
#         [-0.0555],
#         [ 0.1040],
#         [-0.0162]])
# Epoch 24, Batch 0:
# Direction vector d (norm): 1.38280189037323
# First 10 values of d: tensor([ 0.0907,  0.3328,  0.1434,  0.2025,  0.0834, -0.0767,  0.1159, -0.2545,
#         -0.1100,  0.1095])
# Gradient vector g (norm): 1.1579418182373047
# First 10 values of g: tensor([[ 0.0346],
#         [ 0.1752],
#         [-0.0594],
#         [ 0.0878],
#         [-0.0366],
#         [-0.0953],
#         [ 0.0052],
#         [-0.0556],
#         [ 0.1039],
#         [-0.0163]])
# Epoch 25, Batch 0:
# Direction vector d (norm): 1.4115558862686157
# First 10 values of d: tensor([ 0.1021,  0.3292,  0.1160,  0.2333,  0.0601, -0.0371,  0.2017, -0.2273,
#         -0.1097,  0.0839])
# Gradient vector g (norm): 1.1589876413345337
# First 10 values of g: tensor([[ 0.0347],
#         [ 0.1753],
#         [-0.0595],
#         [ 0.0880],
#         [-0.0367],
#         [-0.0953],
#         [ 0.0052],
#         [-0.0555],
#         [ 0.1038],
#         [-0.0164]])
# Epoch 26, Batch 0:
# Direction vector d (norm): 1.394295334815979
# First 10 values of d: tensor([ 0.0834,  0.3321,  0.1604,  0.2104,  0.0596, -0.0549,  0.1409, -0.2668,
#         -0.1722,  0.1094])
# Gradient vector g (norm): 1.1599968671798706
# First 10 values of g: tensor([[ 0.0346],
#         [ 0.1754],
#         [-0.0596],
#         [ 0.0882],
#         [-0.0368],
#         [-0.0954],
#         [ 0.0049],
#         [-0.0557],
#         [ 0.1037],
#         [-0.0164]])
# Epoch 27, Batch 0:
# Direction vector d (norm): 1.401181697845459
# First 10 values of d: tensor([ 0.1217,  0.3112,  0.0767,  0.2128,  0.1156, -0.0760,  0.1775, -0.2418,
#         -0.0509,  0.0904])
# Gradient vector g (norm): 1.1599509716033936
# First 10 values of g: tensor([[ 0.0346],
#         [ 0.1753],
#         [-0.0596],
#         [ 0.0882],
#         [-0.0368],
#         [-0.0954],
#         [ 0.0050],
#         [-0.0555],
#         [ 0.1037],
#         [-0.0164]])
# Epoch 28, Batch 0:
# Direction vector d (norm): 1.41376793384552
# First 10 values of d: tensor([ 0.1021,  0.3275,  0.1139,  0.2353,  0.0614, -0.0351,  0.2049, -0.2275,
#         -0.1084,  0.0838])
# Gradient vector g (norm): 1.1649798154830933
# First 10 values of g: tensor([[ 0.0347],
#         [ 0.1754],
#         [-0.0595],
#         [ 0.0881],
#         [-0.0367],
#         [-0.0955],
#         [ 0.0050],
#         [-0.0556],
#         [ 0.1037],
#         [-0.0164]])
# Epoch 29, Batch 0:
# Direction vector d (norm): 1.3830596208572388
# First 10 values of d: tensor([ 0.0779,  0.3323,  0.1578,  0.2113,  0.0534, -0.0594,  0.1429, -0.2685,
#         -0.1724,  0.1123])
# Gradient vector g (norm): 1.160225510597229
# First 10 values of g: tensor([[ 0.0346],
#         [ 0.1754],
#         [-0.0596],
#         [ 0.0883],
#         [-0.0368],
#         [-0.0955],
#         [ 0.0049],
#         [-0.0556],
#         [ 0.1037],
#         [-0.0164]])
# Epoch 30, Batch 0:
# Direction vector d (norm): 1.43816339969635
# First 10 values of d: tensor([ 0.0553,  0.3020,  0.1541,  0.2098,  0.0556, -0.1098,  0.3697, -0.1605,
#          0.0560,  0.1593])
# Gradient vector g (norm): 1.1597920656204224
# First 10 values of g: tensor([[ 0.0345],
#         [ 0.1753],
#         [-0.0596],
#         [ 0.0883],
#         [-0.0368],
#         [-0.0953],
#         [ 0.0050],
#         [-0.0555],
#         [ 0.1037],
#         [-0.0164]])
# Epoch 30, Loss: 0.4176924526691437
# Epoch 31, Batch 0:
# Direction vector d (norm): 1.4152016639709473
# First 10 values of d: tensor([ 0.0813,  0.3299,  0.1593,  0.2103,  0.0579, -0.0564,  0.1449, -0.2697,
#         -0.1715,  0.1142])
# Gradient vector g (norm): 1.165500521659851
# First 10 values of g: tensor([[ 0.0345],
#         [ 0.1752],
#         [-0.0595],
#         [ 0.0884],
#         [-0.0368],
#         [-0.0955],
#         [ 0.0051],
#         [-0.0556],
#         [ 0.1037],
#         [-0.0162]])
# Epoch 32, Batch 0:
# Direction vector d (norm): 1.3946585655212402
# First 10 values of d: tensor([ 0.1209,  0.3202,  0.0797,  0.2354,  0.0504, -0.0427,  0.1780, -0.2401,
#         -0.0913,  0.1045])
# Gradient vector g (norm): 1.160202145576477
# First 10 values of g: tensor([[ 0.0344],
#         [ 0.1752],
#         [-0.0596],
#         [ 0.0886],
#         [-0.0370],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0556],
#         [ 0.1036],
#         [-0.0162]])
# Epoch 33, Batch 0:
# Direction vector d (norm): 1.413161277770996
# First 10 values of d: tensor([ 0.0830,  0.3325,  0.1583,  0.2101,  0.0580, -0.0537,  0.1397, -0.2660,
#         -0.1717,  0.1093])
# Gradient vector g (norm): 1.1604751348495483
# First 10 values of g: tensor([[ 0.0344],
#         [ 0.1753],
#         [-0.0596],
#         [ 0.0886],
#         [-0.0370],
#         [-0.0955],
#         [ 0.0050],
#         [-0.0559],
#         [ 0.1035],
#         [-0.0162]])
# Epoch 34, Batch 0:
# Direction vector d (norm): 1.3803648948669434
# First 10 values of d: tensor([ 0.1191,  0.3107,  0.0761,  0.2124,  0.1131, -0.0744,  0.1767, -0.2405,
#         -0.0518,  0.0896])
# Gradient vector g (norm): 1.1609281301498413
# First 10 values of g: tensor([[ 0.0345],
#         [ 0.1753],
#         [-0.0597],
#         [ 0.0886],
#         [-0.0368],
#         [-0.0955],
#         [ 0.0049],
#         [-0.0557],
#         [ 0.1036],
#         [-0.0162]])
# Epoch 35, Batch 0:
# Direction vector d (norm): 1.4267182350158691
# First 10 values of d: tensor([ 0.0790,  0.3339,  0.1725,  0.2172,  0.0503, -0.0582,  0.1511, -0.2344,
#         -0.1741,  0.1110])
# Gradient vector g (norm): 1.1613839864730835
# First 10 values of g: tensor([[ 0.0345],
#         [ 0.1753],
#         [-0.0597],
#         [ 0.0886],
#         [-0.0369],
#         [-0.0956],
#         [ 0.0049],
#         [-0.0557],
#         [ 0.1035],
#         [-0.0162]])
# Epoch 36, Batch 0:
# Direction vector d (norm): 1.394544243812561
# First 10 values of d: tensor([ 0.0406,  0.3039,  0.1698,  0.2192,  0.0247, -0.0906,  0.3946, -0.1699,
#         -0.0094,  0.1559])
# Gradient vector g (norm): 1.161327600479126
# First 10 values of g: tensor([[ 0.0345],
#         [ 0.1753],
#         [-0.0597],
#         [ 0.0887],
#         [-0.0368],
#         [-0.0954],
#         [ 0.0049],
#         [-0.0555],
#         [ 0.1035],
#         [-0.0162]])
# Epoch 37, Batch 0:
# Direction vector d (norm): 1.4149190187454224
# First 10 values of d: tensor([ 0.0929,  0.3285,  0.1482,  0.2014,  0.0874, -0.0724,  0.1228, -0.2568,
#         -0.1065,  0.1147])
# Gradient vector g (norm): 1.1610913276672363
# First 10 values of g: tensor([[ 0.0342],
#         [ 0.1751],
#         [-0.0597],
#         [ 0.0888],
#         [-0.0369],
#         [-0.0954],
#         [ 0.0051],
#         [-0.0555],
#         [ 0.1035],
#         [-0.0162]])
# Epoch 38, Batch 0:
# Direction vector d (norm): 1.3759759664535522
# First 10 values of d: tensor([ 0.0886,  0.3124,  0.1189,  0.2145,  0.0781, -0.0390,  0.1259, -0.2677,
#         -0.1445,  0.1075])
# Gradient vector g (norm): 1.1663049459457397
# First 10 values of g: tensor([[ 0.0344],
#         [ 0.1752],
#         [-0.0596],
#         [ 0.0889],
#         [-0.0368],
#         [-0.0954],
#         [ 0.0050],
#         [-0.0555],
#         [ 0.1036],
#         [-0.0162]])
# Epoch 39, Batch 0:
# Direction vector d (norm): 1.4060291051864624
# First 10 values of d: tensor([ 0.1247,  0.3372,  0.1179,  0.2349,  0.0508, -0.0799,  0.1756, -0.1963,
#         -0.0555,  0.1151])
# Gradient vector g (norm): 1.161587119102478
# First 10 values of g: tensor([[ 0.0342],
#         [ 0.1753],
#         [-0.0597],
#         [ 0.0889],
#         [-0.0369],
#         [-0.0955],
#         [ 0.0048],
#         [-0.0557],
#         [ 0.1035],
#         [-0.0162]])
# Epoch 40, Batch 0:
# Direction vector d (norm): 1.3809211254119873
# First 10 values of d: tensor([ 0.1045,  0.3232,  0.1012,  0.2281,  0.0648, -0.0303,  0.1949, -0.2626,
#         -0.1102,  0.0851])
# Gradient vector g (norm): 1.1632317304611206
# First 10 values of g: tensor([[ 0.0341],
#         [ 0.1753],
#         [-0.0598],
#         [ 0.0893],
#         [-0.0369],
#         [-0.0957],
#         [ 0.0049],
#         [-0.0556],
#         [ 0.1035],
#         [-0.0161]])
# Epoch 40, Loss: 0.4176819920539856
# Epoch 41, Batch 0:
# Direction vector d (norm): 1.3953278064727783
# First 10 values of d: tensor([ 0.1100,  0.3309,  0.1185,  0.2037,  0.0922, -0.0850,  0.1937, -0.2464,
#         -0.0871,  0.0873])
# Gradient vector g (norm): 1.1631325483322144
# First 10 values of g: tensor([[ 0.0340],
#         [ 0.1752],
#         [-0.0599],
#         [ 0.0894],
#         [-0.0369],
#         [-0.0957],
#         [ 0.0048],
#         [-0.0557],
#         [ 0.1034],
#         [-0.0160]])
# Epoch 42, Batch 0:
# Direction vector d (norm): 1.389013648033142
# First 10 values of d: tensor([ 0.0820,  0.3314,  0.1591,  0.2094,  0.0554, -0.0516,  0.1416, -0.2689,
#         -0.1758,  0.1106])
# Gradient vector g (norm): 1.168533444404602
# First 10 values of g: tensor([[ 0.0340],
#         [ 0.1752],
#         [-0.0598],
#         [ 0.0895],
#         [-0.0369],
#         [-0.0959],
#         [ 0.0047],
#         [-0.0559],
#         [ 0.1033],
#         [-0.0158]])
# Epoch 43, Batch 0:
# Direction vector d (norm): 1.4201490879058838
# First 10 values of d: tensor([ 0.0549,  0.3030,  0.1544,  0.2086,  0.0529, -0.1043,  0.3711, -0.1590,
#          0.0538,  0.1568])
# Gradient vector g (norm): 1.1626935005187988
# First 10 values of g: tensor([[ 0.0338],
#         [ 0.1752],
#         [-0.0599],
#         [ 0.0896],
#         [-0.0369],
#         [-0.0958],
#         [ 0.0049],
#         [-0.0558],
#         [ 0.1033],
#         [-0.0159]])
# Epoch 44, Batch 0:
# Direction vector d (norm): 1.3788782358169556
# First 10 values of d: tensor([ 0.1003,  0.3260,  0.1345,  0.2176,  0.0356, -0.0649,  0.1314, -0.2448,
#         -0.1523,  0.1337])
# Gradient vector g (norm): 1.1627912521362305
# First 10 values of g: tensor([[ 0.0335],
#         [ 0.1751],
#         [-0.0599],
#         [ 0.0897],
#         [-0.0370],
#         [-0.0958],
#         [ 0.0051],
#         [-0.0559],
#         [ 0.1034],
#         [-0.0158]])
# Epoch 45, Batch 0:
# Direction vector d (norm): 1.4171838760375977
# First 10 values of d: tensor([ 0.0826,  0.3324,  0.1622,  0.2087,  0.0566, -0.0500,  0.1411, -0.2682,
#         -0.1778,  0.1074])
# Gradient vector g (norm): 1.1642333269119263
# First 10 values of g: tensor([[ 0.0335],
#         [ 0.1753],
#         [-0.0599],
#         [ 0.0899],
#         [-0.0371],
#         [-0.0961],
#         [ 0.0049],
#         [-0.0560],
#         [ 0.1032],
#         [-0.0157]])
# Epoch 46, Batch 0:
# Direction vector d (norm): 1.3695321083068848
# First 10 values of d: tensor([ 0.1244,  0.3093,  0.0758,  0.2121,  0.1148, -0.0633,  0.1753, -0.2402,
#         -0.0576,  0.0857])
# Gradient vector g (norm): 1.1635332107543945
# First 10 values of g: tensor([[ 0.0335],
#         [ 0.1752],
#         [-0.0599],
#         [ 0.0899],
#         [-0.0369],
#         [-0.0961],
#         [ 0.0049],
#         [-0.0559],
#         [ 0.1033],
#         [-0.0156]])
# Epoch 47, Batch 0:
# Direction vector d (norm): 1.419399380683899
# First 10 values of d: tensor([ 0.0213,  0.3119,  0.2235,  0.1984,  0.0156, -0.1084,  0.3421, -0.1763,
#         -0.0740,  0.1786])
# Gradient vector g (norm): 1.1650066375732422
# First 10 values of g: tensor([[ 0.0335],
#         [ 0.1754],
#         [-0.0600],
#         [ 0.0901],
#         [-0.0370],
#         [-0.0964],
#         [ 0.0047],
#         [-0.0561],
#         [ 0.1032],
#         [-0.0155]])
# Epoch 48, Batch 0:
# Direction vector d (norm): 1.37539541721344
# First 10 values of d: tensor([ 0.0911,  0.3294,  0.1481,  0.2006,  0.0812, -0.0653,  0.1219, -0.2519,
#         -0.1136,  0.1083])
# Gradient vector g (norm): 1.1720679998397827
# First 10 values of g: tensor([[ 0.0334],
#         [ 0.1752],
#         [-0.0600],
#         [ 0.0901],
#         [-0.0369],
#         [-0.0963],
#         [ 0.0050],
#         [-0.0559],
#         [ 0.1033],
#         [-0.0154]])
# Epoch 49, Batch 0:
# Direction vector d (norm): 1.3927199840545654
# First 10 values of d: tensor([ 0.1217,  0.3207,  0.0780,  0.2337,  0.0444, -0.0362,  0.1776, -0.2401,
#         -0.0937,  0.1027])
# Gradient vector g (norm): 1.1648130416870117
# First 10 values of g: tensor([[ 0.0332],
#         [ 0.1752],
#         [-0.0601],
#         [ 0.0902],
#         [-0.0371],
#         [-0.0963],
#         [ 0.0050],
#         [-0.0561],
#         [ 0.1032],
#         [-0.0154]])
# Epoch 50, Batch 0:
# Direction vector d (norm): 1.3865975141525269
# First 10 values of d: tensor([ 0.0919,  0.3392,  0.1745,  0.1895,  0.0798, -0.1044,  0.1364, -0.2482,
#         -0.1481,  0.1143])
# Gradient vector g (norm): 1.1653262376785278
# First 10 values of g: tensor([[ 0.0331],
#         [ 0.1752],
#         [-0.0601],
#         [ 0.0904],
#         [-0.0370],
#         [-0.0965],
#         [ 0.0051],
#         [-0.0560],
#         [ 0.1032],
#         [-0.0153]])
# Epoch 50, Loss: 0.4183295965194702
# Epoch 51, Batch 0:
# Direction vector d (norm): 1.4161721467971802
# First 10 values of d: tensor([ 0.0504,  0.2865,  0.1244,  0.2202,  0.0414, -0.0689,  0.3813, -0.1697,
#          0.0183,  0.1509])
# Gradient vector g (norm): 1.165297269821167
# First 10 values of g: tensor([[ 0.0331],
#         [ 0.1753],
#         [-0.0601],
#         [ 0.0904],
#         [-0.0371],
#         [-0.0965],
#         [ 0.0050],
#         [-0.0561],
#         [ 0.1031],
#         [-0.0153]])
# Epoch 52, Batch 0:
# Direction vector d (norm): 1.4002947807312012
# First 10 values of d: tensor([ 0.0804,  0.3341,  0.1633,  0.2067,  0.0537, -0.0469,  0.1466, -0.2650,
#         -0.1727,  0.1064])
# Gradient vector g (norm): 1.1651958227157593
# First 10 values of g: tensor([[ 0.0328],
#         [ 0.1751],
#         [-0.0602],
#         [ 0.0906],
#         [-0.0371],
#         [-0.0963],
#         [ 0.0054],
#         [-0.0560],
#         [ 0.1032],
#         [-0.0152]])
# Epoch 53, Batch 0:
# Direction vector d (norm): 1.3697893619537354
# First 10 values of d: tensor([ 0.0994,  0.3214,  0.1351,  0.1924,  0.0985, -0.0891,  0.1213, -0.2475,
#         -0.1206,  0.1111])
# Gradient vector g (norm): 1.1729422807693481
# First 10 values of g: tensor([[ 0.0326],
#         [ 0.1751],
#         [-0.0601],
#         [ 0.0906],
#         [-0.0371],
#         [-0.0965],
#         [ 0.0053],
#         [-0.0562],
#         [ 0.1032],
#         [-0.0151]])
# Epoch 54, Batch 0:
# Direction vector d (norm): 1.3906012773513794
# First 10 values of d: tensor([ 0.1000,  0.3309,  0.1068,  0.2232,  0.0599, -0.0281,  0.1956, -0.2586,
#         -0.1093,  0.0774])
# Gradient vector g (norm): 1.16647469997406
# First 10 values of g: tensor([[ 0.0327],
#         [ 0.1752],
#         [-0.0603],
#         [ 0.0908],
#         [-0.0371],
#         [-0.0965],
#         [ 0.0053],
#         [-0.0562],
#         [ 0.1032],
#         [-0.0151]])
# Epoch 55, Batch 0:
# Direction vector d (norm): 1.3675611019134521
# First 10 values of d: tensor([ 0.1240,  0.3409,  0.1060,  0.2198,  0.0477, -0.0719,  0.1692, -0.2294,
#         -0.0564,  0.1067])
# Gradient vector g (norm): 1.1670242547988892
# First 10 values of g: tensor([[ 0.0326],
#         [ 0.1752],
#         [-0.0604],
#         [ 0.0907],
#         [-0.0372],
#         [-0.0965],
#         [ 0.0052],
#         [-0.0564],
#         [ 0.1031],
#         [-0.0152]])
# Epoch 56, Batch 0:
# Direction vector d (norm): 1.3985307216644287
# First 10 values of d: tensor([ 0.0867,  0.3223,  0.1491,  0.2012,  0.0696, -0.0725,  0.1486, -0.2623,
#         -0.1839,  0.1118])
# Gradient vector g (norm): 1.1750003099441528
# First 10 values of g: tensor([[ 0.0326],
#         [ 0.1751],
#         [-0.0604],
#         [ 0.0909],
#         [-0.0373],
#         [-0.0965],
#         [ 0.0053],
#         [-0.0562],
#         [ 0.1030],
#         [-0.0152]])
# Epoch 57, Batch 0:
# Direction vector d (norm): 1.4168816804885864
# First 10 values of d: tensor([ 0.0570,  0.2910,  0.1287,  0.2182,  0.0424, -0.0660,  0.3787, -0.1684,
#          0.0149,  0.1473])
# Gradient vector g (norm): 1.1655597686767578
# First 10 values of g: tensor([[ 0.0321],
#         [ 0.1748],
#         [-0.0603],
#         [ 0.0907],
#         [-0.0372],
#         [-0.0963],
#         [ 0.0057],
#         [-0.0563],
#         [ 0.1032],
#         [-0.0152]])
# Epoch 58, Batch 0:
# Direction vector d (norm): 1.3815826177597046
# First 10 values of d: tensor([ 0.0810,  0.3394,  0.1652,  0.2061,  0.0492, -0.0504,  0.1481, -0.2642,
#         -0.1724,  0.1050])
# Gradient vector g (norm): 1.1728839874267578
# First 10 values of g: tensor([[ 0.0322],
#         [ 0.1747],
#         [-0.0603],
#         [ 0.0907],
#         [-0.0371],
#         [-0.0962],
#         [ 0.0059],
#         [-0.0561],
#         [ 0.1033],
#         [-0.0151]])
# Epoch 59, Batch 0:
# Direction vector d (norm): 1.3945050239562988
# First 10 values of d: tensor([ 0.0889,  0.3261,  0.1517,  0.1996,  0.0717, -0.0712,  0.1471, -0.2614,
#         -0.1862,  0.1076])
# Gradient vector g (norm): 1.166682243347168
# First 10 values of g: tensor([[ 0.0323],
#         [ 0.1750],
#         [-0.0604],
#         [ 0.0909],
#         [-0.0372],
#         [-0.0965],
#         [ 0.0056],
#         [-0.0563],
#         [ 0.1031],
#         [-0.0151]])
# Epoch 60, Batch 0:
# Direction vector d (norm): 1.4196805953979492
# First 10 values of d: tensor([ 0.0585,  0.3064,  0.1573,  0.2050,  0.0501, -0.0997,  0.3665, -0.1590,
#          0.0498,  0.1509])
# Gradient vector g (norm): 1.1672216653823853
# First 10 values of g: tensor([[ 0.0322],
#         [ 0.1749],
#         [-0.0604],
#         [ 0.0909],
#         [-0.0373],
#         [-0.0964],
#         [ 0.0057],
#         [-0.0563],
#         [ 0.1031],
#         [-0.0151]])
# Epoch 60, Loss: 0.41955330967903137
# Epoch 61, Batch 0:
# Direction vector d (norm): 1.3769128322601318
# First 10 values of d: tensor([ 0.0844,  0.3343,  0.1601,  0.2070,  0.0503, -0.0470,  0.1445, -0.2656,
#         -0.1759,  0.1055])
# Gradient vector g (norm): 1.1745649576187134
# First 10 values of g: tensor([[ 0.0320],
#         [ 0.1748],
#         [-0.0604],
#         [ 0.0910],
#         [-0.0373],
#         [-0.0963],
#         [ 0.0058],
#         [-0.0564],
#         [ 0.1032],
#         [-0.0150]])
# Epoch 62, Batch 0:
# Direction vector d (norm): 1.4039814472198486
# First 10 values of d: tensor([ 0.1018,  0.3206,  0.1296,  0.1924,  0.0970, -0.0885,  0.1204, -0.2500,
#         -0.1248,  0.1108])
# Gradient vector g (norm): 1.1664655208587646
# First 10 values of g: tensor([[ 0.0320],
#         [ 0.1747],
#         [-0.0604],
#         [ 0.0910],
#         [-0.0373],
#         [-0.0963],
#         [ 0.0058],
#         [-0.0563],
#         [ 0.1031],
#         [-0.0150]])
# Epoch 63, Batch 0:
# Direction vector d (norm): 1.3743765354156494
# First 10 values of d: tensor([ 0.1020,  0.3301,  0.1046,  0.2216,  0.0570, -0.0282,  0.1939, -0.2606,
#         -0.1119,  0.0788])
# Gradient vector g (norm): 1.175747275352478
# First 10 values of g: tensor([[ 0.0320],
#         [ 0.1749],
#         [-0.0604],
#         [ 0.0912],
#         [-0.0374],
#         [-0.0965],
#         [ 0.0056],
#         [-0.0565],
#         [ 0.1030],
#         [-0.0149]])
# Epoch 64, Batch 0:
# Direction vector d (norm): 1.3880317211151123
# First 10 values of d: tensor([ 0.1047,  0.3477,  0.1314,  0.2041,  0.0645, -0.0573,  0.1856, -0.2526,
#         -0.0799,  0.0800])
# Gradient vector g (norm): 1.1687654256820679
# First 10 values of g: tensor([[ 0.0320],
#         [ 0.1750],
#         [-0.0605],
#         [ 0.0913],
#         [-0.0375],
#         [-0.0965],
#         [ 0.0056],
#         [-0.0565],
#         [ 0.1030],
#         [-0.0150]])
# Epoch 65, Batch 0:
# Direction vector d (norm): 1.4069072008132935
# First 10 values of d: tensor([ 0.0878,  0.3236,  0.1473,  0.1995,  0.0677, -0.0709,  0.1471, -0.2599,
#         -0.1837,  0.1098])
# Gradient vector g (norm): 1.1754112243652344
# First 10 values of g: tensor([[ 0.0319],
#         [ 0.1749],
#         [-0.0604],
#         [ 0.0912],
#         [-0.0374],
#         [-0.0965],
#         [ 0.0057],
#         [-0.0565],
#         [ 0.1030],
#         [-0.0149]])
# Epoch 66, Batch 0:
# Direction vector d (norm): 1.3909066915512085
# First 10 values of d: tensor([ 0.0441,  0.3068,  0.1671,  0.2115,  0.0182, -0.0834,  0.3904, -0.1696,
#         -0.0136,  0.1515])
# Gradient vector g (norm): 1.1761345863342285
# First 10 values of g: tensor([[ 0.0319],
#         [ 0.1748],
#         [-0.0605],
#         [ 0.0914],
#         [-0.0375],
#         [-0.0965],
#         [ 0.0057],
#         [-0.0565],
#         [ 0.1029],
#         [-0.0149]])
# Epoch 67, Batch 0:
# Direction vector d (norm): 1.39517343044281
# First 10 values of d: tensor([ 0.0919,  0.3170,  0.1178,  0.2122,  0.0694, -0.0356,  0.1341, -0.2611,
#         -0.1421,  0.1073])
# Gradient vector g (norm): 1.1675901412963867
# First 10 values of g: tensor([[ 0.0314],
#         [ 0.1744],
#         [-0.0605],
#         [ 0.0913],
#         [-0.0374],
#         [-0.0963],
#         [ 0.0061],
#         [-0.0565],
#         [ 0.1031],
#         [-0.0149]])
# Epoch 68, Batch 0:
# Direction vector d (norm): 1.3918659687042236
# First 10 values of d: tensor([ 0.0936,  0.3434,  0.1790,  0.1794,  0.0777, -0.1014,  0.1336, -0.2488,
#         -0.1548,  0.1081])
# Gradient vector g (norm): 1.1762624979019165
# First 10 values of g: tensor([[ 0.0316],
#         [ 0.1747],
#         [-0.0605],
#         [ 0.0913],
#         [-0.0374],
#         [-0.0964],
#         [ 0.0060],
#         [-0.0565],
#         [ 0.1030],
#         [-0.0149]])
# Epoch 69, Batch 0:
# Direction vector d (norm): 1.3858190774917603
# First 10 values of d: tensor([ 0.0572,  0.2866,  0.1245,  0.2214,  0.0399, -0.0684,  0.3772, -0.1664,
#          0.0168,  0.1507])
# Gradient vector g (norm): 1.177121639251709
# First 10 values of g: tensor([[ 0.0318],
#         [ 0.1748],
#         [-0.0606],
#         [ 0.0913],
#         [-0.0373],
#         [-0.0965],
#         [ 0.0057],
#         [-0.0566],
#         [ 0.1030],
#         [-0.0149]])
# Epoch 70, Batch 0:
# Direction vector d (norm): 1.4133607149124146
# First 10 values of d: tensor([ 0.0836,  0.3546,  0.1884,  0.1855,  0.0539, -0.0814,  0.1354, -0.2561,
#         -0.1429,  0.1078])
# Gradient vector g (norm): 1.168028473854065
# First 10 values of g: tensor([[ 0.0315],
#         [ 0.1745],
#         [-0.0605],
#         [ 0.0913],
#         [-0.0374],
#         [-0.0963],
#         [ 0.0061],
#         [-0.0566],
#         [ 0.1030],
#         [-0.0148]])
# Epoch 70, Loss: 0.4194584786891937
# Epoch 71, Batch 0:
# Direction vector d (norm): 1.374715805053711
# First 10 values of d: tensor([ 0.0993,  0.3036,  0.1050,  0.2075,  0.0882, -0.0567,  0.1306, -0.2562,
#         -0.1552,  0.1091])
# Gradient vector g (norm): 1.1691006422042847
# First 10 values of g: tensor([[ 0.0315],
#         [ 0.1745],
#         [-0.0606],
#         [ 0.0915],
#         [-0.0374],
#         [-0.0964],
#         [ 0.0060],
#         [-0.0566],
#         [ 0.1030],
#         [-0.0147]])
# Epoch 72, Batch 0:
# Direction vector d (norm): 1.3652604818344116
# First 10 values of d: tensor([ 0.1071,  0.3484,  0.1317,  0.2034,  0.0639, -0.0580,  0.1833, -0.2505,
#         -0.0820,  0.0794])
# Gradient vector g (norm): 1.1768478155136108
# First 10 values of g: tensor([[ 0.0313],
#         [ 0.1745],
#         [-0.0606],
#         [ 0.0914],
#         [-0.0375],
#         [-0.0963],
#         [ 0.0059],
#         [-0.0568],
#         [ 0.1030],
#         [-0.0147]])
# Epoch 73, Batch 0:
# Direction vector d (norm): 1.3969141244888306
# First 10 values of d: tensor([ 0.1045,  0.3321,  0.1039,  0.2203,  0.0548, -0.0267,  0.1966, -0.2572,
#         -0.1115,  0.0763])
# Gradient vector g (norm): 1.1763995885849
# First 10 values of g: tensor([[ 0.0311],
#         [ 0.1744],
#         [-0.0605],
#         [ 0.0915],
#         [-0.0375],
#         [-0.0963],
#         [ 0.0059],
#         [-0.0569],
#         [ 0.1030],
#         [-0.0146]])
# Epoch 74, Batch 0:
# Direction vector d (norm): 1.3860803842544556
# First 10 values of d: tensor([ 0.0354,  0.3019,  0.2092,  0.1885,  0.0284, -0.1258,  0.3440, -0.1676,
#         -0.0868,  0.1793])
# Gradient vector g (norm): 1.184752345085144
# First 10 values of g: tensor([[ 0.0310],
#         [ 0.1743],
#         [-0.0606],
#         [ 0.0916],
#         [-0.0376],
#         [-0.0964],
#         [ 0.0059],
#         [-0.0570],
#         [ 0.1029],
#         [-0.0146]])
# Epoch 75, Batch 0:
# Direction vector d (norm): 1.3823156356811523
# First 10 values of d: tensor([ 0.0966,  0.3188,  0.1189,  0.2112,  0.0677, -0.0361,  0.1341, -0.2593,
#         -0.1459,  0.1063])
# Gradient vector g (norm): 1.1844375133514404
# First 10 values of g: tensor([[ 0.0306],
#         [ 0.1740],
#         [-0.0605],
#         [ 0.0916],
#         [-0.0374],
#         [-0.0963],
#         [ 0.0062],
#         [-0.0569],
#         [ 0.1031],
#         [-0.0145]])
# Epoch 76, Batch 0:
# Direction vector d (norm): 1.403216004371643
# First 10 values of d: tensor([ 0.0913,  0.3560,  0.1862,  0.1844,  0.0552, -0.0819,  0.1312, -0.2567,
#         -0.1466,  0.1036])
# Gradient vector g (norm): 1.1771109104156494
# First 10 values of g: tensor([[ 0.0307],
#         [ 0.1742],
#         [-0.0606],
#         [ 0.0915],
#         [-0.0376],
#         [-0.0963],
#         [ 0.0058],
#         [-0.0573],
#         [ 0.1030],
#         [-0.0145]])
# Epoch 77, Batch 0:
# Direction vector d (norm): 1.416673183441162
# First 10 values of d: tensor([ 0.0585,  0.2664,  0.1013,  0.2130,  0.0585, -0.0846,  0.3887, -0.1556,
#          0.0086,  0.1536])
# Gradient vector g (norm): 1.1706690788269043
# First 10 values of g: tensor([[ 0.0309],
#         [ 0.1742],
#         [-0.0607],
#         [ 0.0916],
#         [-0.0375],
#         [-0.0963],
#         [ 0.0057],
#         [-0.0571],
#         [ 0.1029],
#         [-0.0145]])
# Epoch 78, Batch 0:
# Direction vector d (norm): 1.3786702156066895
# First 10 values of d: tensor([ 0.0880,  0.3542,  0.1863,  0.1851,  0.0540, -0.0826,  0.1391, -0.2530,
#         -0.1425,  0.1056])
# Gradient vector g (norm): 1.1857062578201294
# First 10 values of g: tensor([[ 0.0307],
#         [ 0.1741],
#         [-0.0606],
#         [ 0.0916],
#         [-0.0376],
#         [-0.0963],
#         [ 0.0059],
#         [-0.0572],
#         [ 0.1029],
#         [-0.0145]])
# Epoch 79, Batch 0:
# Direction vector d (norm): 1.3548541069030762
# First 10 values of d: tensor([ 0.0947,  0.3162,  0.1177,  0.2119,  0.0678, -0.0366,  0.1302, -0.2609,
#         -0.1465,  0.1024])
# Gradient vector g (norm): 1.1790329217910767
# First 10 values of g: tensor([[ 0.0308],
#         [ 0.1741],
#         [-0.0607],
#         [ 0.0918],
#         [-0.0376],
#         [-0.0963],
#         [ 0.0055],
#         [-0.0572],
#         [ 0.1029],
#         [-0.0144]])
# Epoch 80, Batch 0:
# Direction vector d (norm): 1.4132080078125
# First 10 values of d: tensor([ 0.0930,  0.3573,  0.1881,  0.1847,  0.0564, -0.0796,  0.1328, -0.2568,
#         -0.1489,  0.1055])
# Gradient vector g (norm): 1.1866627931594849
# First 10 values of g: tensor([[ 0.0305],
#         [ 0.1740],
#         [-0.0607],
#         [ 0.0916],
#         [-0.0376],
#         [-0.0962],
#         [ 0.0057],
#         [-0.0573],
#         [ 0.1029],
#         [-0.0146]])
# Epoch 80, Loss: 0.42296871542930603
# Epoch 81, Batch 0:
# Direction vector d (norm): 1.4213732481002808
# First 10 values of d: tensor([ 0.0526,  0.2820,  0.1192,  0.2161,  0.0387, -0.0637,  0.3840, -0.1624,
#          0.0179,  0.1527])
# Gradient vector g (norm): 1.180007815361023
# First 10 values of g: tensor([[ 0.0307],
#         [ 0.1740],
#         [-0.0607],
#         [ 0.0916],
#         [-0.0375],
#         [-0.0961],
#         [ 0.0056],
#         [-0.0574],
#         [ 0.1030],
#         [-0.0145]])
# Epoch 82, Batch 0:
# Direction vector d (norm): 1.401464819908142
# First 10 values of d: tensor([ 0.0839,  0.3376,  0.1613,  0.1981,  0.0461, -0.0520,  0.1521, -0.2608,
#         -0.1779,  0.1015])
# Gradient vector g (norm): 1.1879568099975586
# First 10 values of g: tensor([[ 0.0305],
#         [ 0.1738],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0381],
#         [-0.0957],
#         [ 0.0060],
#         [-0.0577],
#         [ 0.1028],
#         [-0.0146]])
# Epoch 83, Batch 0:
# Direction vector d (norm): 1.3707871437072754
# First 10 values of d: tensor([ 0.1036,  0.3036,  0.1067,  0.2066,  0.0895, -0.0591,  0.1351, -0.2508,
#         -0.1552,  0.1088])
# Gradient vector g (norm): 1.1798503398895264
# First 10 values of g: tensor([[ 0.0306],
#         [ 0.1737],
#         [-0.0608],
#         [ 0.0917],
#         [-0.0378],
#         [-0.0958],
#         [ 0.0057],
#         [-0.0576],
#         [ 0.1028],
#         [-0.0145]])
# Epoch 84, Batch 0:
# Direction vector d (norm): 1.39589524269104
# First 10 values of d: tensor([ 0.0898,  0.3551,  0.1875,  0.1856,  0.0565, -0.0835,  0.1329, -0.2543,
#         -0.1468,  0.1058])
# Gradient vector g (norm): 1.1808648109436035
# First 10 values of g: tensor([[ 0.0306],
#         [ 0.1738],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0379],
#         [-0.0958],
#         [ 0.0056],
#         [-0.0577],
#         [ 0.1027],
#         [-0.0145]])
# Epoch 85, Batch 0:
# Direction vector d (norm): 1.4056888818740845
# First 10 values of d: tensor([ 0.0546,  0.2850,  0.1210,  0.2172,  0.0398, -0.0633,  0.3837, -0.1623,
#          0.0177,  0.1538])
# Gradient vector g (norm): 1.1883825063705444
# First 10 values of g: tensor([[ 0.0304],
#         [ 0.1736],
#         [-0.0608],
#         [ 0.0915],
#         [-0.0376],
#         [-0.0958],
#         [ 0.0057],
#         [-0.0575],
#         [ 0.1029],
#         [-0.0145]])
# Epoch 86, Batch 0:
# Direction vector d (norm): 1.4090611934661865
# First 10 values of d: tensor([ 0.0905,  0.3564,  0.1881,  0.1867,  0.0573, -0.0831,  0.1416, -0.2552,
#         -0.1430,  0.1070])
# Gradient vector g (norm): 1.1802605390548706
# First 10 values of g: tensor([[ 0.0305],
#         [ 0.1736],
#         [-0.0607],
#         [ 0.0915],
#         [-0.0378],
#         [-0.0956],
#         [ 0.0057],
#         [-0.0575],
#         [ 0.1028],
#         [-0.0146]])
# Epoch 87, Batch 0:
# Direction vector d (norm): 1.3889728784561157
# First 10 values of d: tensor([ 0.0978,  0.3176,  0.1184,  0.2143,  0.0692, -0.0393,  0.1318, -0.2608,
#         -0.1463,  0.1040])
# Gradient vector g (norm): 1.1818448305130005
# First 10 values of g: tensor([[ 0.0306],
#         [ 0.1737],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0377],
#         [-0.0957],
#         [ 0.0055],
#         [-0.0576],
#         [ 0.1029],
#         [-0.0145]])
# Epoch 88, Batch 0:
# Direction vector d (norm): 1.403643250465393
# First 10 values of d: tensor([ 0.1145,  0.3193,  0.0911,  0.2120,  0.0778, -0.0491,  0.2040, -0.2496,
#         -0.1261,  0.0784])
# Gradient vector g (norm): 1.1894840002059937
# First 10 values of g: tensor([[ 0.0305],
#         [ 0.1736],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0381],
#         [-0.0954],
#         [ 0.0058],
#         [-0.0579],
#         [ 0.1026],
#         [-0.0146]])
# Epoch 89, Batch 0:
# Direction vector d (norm): 1.3690731525421143
# First 10 values of d: tensor([ 0.0798,  0.3476,  0.1788,  0.1873,  0.0568, -0.0802,  0.1367, -0.2518,
#         -0.1420,  0.1109])
# Gradient vector g (norm): 1.1824721097946167
# First 10 values of g: tensor([[ 0.0306],
#         [ 0.1736],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0379],
#         [-0.0954],
#         [ 0.0057],
#         [-0.0577],
#         [ 0.1027],
#         [-0.0146]])
# Epoch 90, Batch 0:
# Direction vector d (norm): 1.4178866147994995
# First 10 values of d: tensor([ 0.0535,  0.2841,  0.1200,  0.2155,  0.0418, -0.0649,  0.3855, -0.1643,
#          0.0177,  0.1548])
# Gradient vector g (norm): 1.1824804544448853
# First 10 values of g: tensor([[ 0.0304],
#         [ 0.1734],
#         [-0.0608],
#         [ 0.0915],
#         [-0.0377],
#         [-0.0955],
#         [ 0.0056],
#         [-0.0576],
#         [ 0.1028],
#         [-0.0146]])
# Epoch 90, Loss: 0.4247231185436249
# Epoch 91, Batch 0:
# Direction vector d (norm): 1.4097617864608765
# First 10 values of d: tensor([ 0.0867,  0.3409,  0.1629,  0.1986,  0.0465, -0.0517,  0.1530, -0.2632,
#         -0.1788,  0.1023])
# Gradient vector g (norm): 1.1824625730514526
# First 10 values of g: tensor([[ 0.0302],
#         [ 0.1733],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0378],
#         [-0.0953],
#         [ 0.0059],
#         [-0.0576],
#         [ 0.1028],
#         [-0.0145]])
# Epoch 92, Batch 0:
# Direction vector d (norm): 1.3995479345321655
# First 10 values of d: tensor([ 0.0989,  0.3205,  0.1207,  0.2121,  0.0695, -0.0389,  0.1304, -0.2615,
#         -0.1459,  0.1064])
# Gradient vector g (norm): 1.1909921169281006
# First 10 values of g: tensor([[ 0.0304],
#         [ 0.1735],
#         [-0.0608],
#         [ 0.0916],
#         [-0.0378],
#         [-0.0955],
#         [ 0.0056],
#         [-0.0578],
#         [ 0.1028],
#         [-0.0144]])
# Epoch 93, Batch 0:
# Direction vector d (norm): 1.3645268678665161
# First 10 values of d: tensor([ 0.0756,  0.3325,  0.1534,  0.1991,  0.0485, -0.0484,  0.1467, -0.2627,
#         -0.1770,  0.1069])
# Gradient vector g (norm): 1.1838253736495972
# First 10 values of g: tensor([[ 0.0304],
#         [ 0.1734],
#         [-0.0609],
#         [ 0.0918],
#         [-0.0381],
#         [-0.0951],
#         [ 0.0058],
#         [-0.0578],
#         [ 0.1026],
#         [-0.0146]])
# Epoch 94, Batch 0:
# Direction vector d (norm): 1.4154717922210693
# First 10 values of d: tensor([ 0.0656,  0.2894,  0.1339,  0.1936,  0.0700, -0.1173,  0.3800, -0.1481,
#          0.0391,  0.1609])
# Gradient vector g (norm): 1.183384895324707
# First 10 values of g: tensor([[ 0.0302],
#         [ 0.1732],
#         [-0.0609],
#         [ 0.0915],
#         [-0.0378],
#         [-0.0951],
#         [ 0.0057],
#         [-0.0577],
#         [ 0.1028],
#         [-0.0146]])
# Epoch 95, Batch 0:
# Direction vector d (norm): 1.4151266813278198
# First 10 values of d: tensor([ 0.0885,  0.3410,  0.1651,  0.2034,  0.0487, -0.0554,  0.1519, -0.2620,
#         -0.1747,  0.1070])
# Gradient vector g (norm): 1.1915476322174072
# First 10 values of g: tensor([[ 0.0303],
#         [ 0.1732],
#         [-0.0609],
#         [ 0.0916],
#         [-0.0378],
#         [-0.0951],
#         [ 0.0059],
#         [-0.0575],
#         [ 0.1028],
#         [-0.0145]])
# Epoch 96, Batch 0:
# Direction vector d (norm): 1.3996877670288086
# First 10 values of d: tensor([ 0.0899,  0.3309,  0.1390,  0.1917,  0.0764, -0.0657,  0.1222, -0.2532,
#         -0.1149,  0.1102])
# Gradient vector g (norm): 1.1842094659805298
# First 10 values of g: tensor([[ 0.0303],
#         [ 0.1733],
#         [-0.0608],
#         [ 0.0915],
#         [-0.0377],
#         [-0.0953],
#         [ 0.0057],
#         [-0.0576],
#         [ 0.1028],
#         [-0.0145]])
# Epoch 97, Batch 0:
# Direction vector d (norm): 1.3505030870437622
# First 10 values of d: tensor([ 0.0836,  0.3118,  0.1123,  0.2057,  0.0666, -0.0348,  0.1351, -0.2612,
#         -0.1479,  0.1053])
# Gradient vector g (norm): 1.1925883293151855
# First 10 values of g: tensor([[ 0.0304],
#         [ 0.1734],
#         [-0.0609],
#         [ 0.0915],
#         [-0.0377],
#         [-0.0953],
#         [ 0.0053],
#         [-0.0576],
#         [ 0.1028],
#         [-0.0146]])
# Epoch 98, Batch 0:
# Direction vector d (norm): 1.4336321353912354
# First 10 values of d: tensor([ 0.0450,  0.3047,  0.1618,  0.2078,  0.0203, -0.0799,  0.3987, -0.1695,
#         -0.0182,  0.1547])
# Gradient vector g (norm): 1.1846983432769775
# First 10 values of g: tensor([[ 0.0301],
#         [ 0.1730],
#         [-0.0609],
#         [ 0.0915],
#         [-0.0377],
#         [-0.0951],
#         [ 0.0056],
#         [-0.0575],
#         [ 0.1029],
#         [-0.0146]])
# Epoch 99, Batch 0:
# Direction vector d (norm): 1.4158543348312378
# First 10 values of d: tensor([ 0.0882,  0.3400,  0.1660,  0.2012,  0.0495, -0.0562,  0.1510, -0.2645,
#         -0.1777,  0.1083])
# Gradient vector g (norm): 1.1854979991912842
# First 10 values of g: tensor([[ 0.0300],
#         [ 0.1729],
#         [-0.0609],
#         [ 0.0917],
#         [-0.0381],
#         [-0.0947],
#         [ 0.0061],
#         [-0.0576],
#         [ 0.1027],
#         [-0.0147]])
# Training complete!
