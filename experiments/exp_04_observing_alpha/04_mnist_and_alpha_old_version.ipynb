# %% [markdown]
# ### Observing alpha
#
#  In this notebook I will attempt to efficiently calculate and observe the optimal step size  during a training loop derived as:
#
# $\alpha^*=\frac{-d^{\top} g}{d^{\top} H d}$

# %%
import torch
import torch.nn as nn
from torch.nn.utils import parameters_to_vector
from torch.nn.utils import vector_to_parameters
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from backpack import backpack, extend
from backpack.extensions import (
    GGNMP,
    HMP,
    KFAC,
    KFLR,
    KFRA,
    PCHMP,
    BatchDiagGGNExact,
    BatchDiagGGNMC,
    BatchDiagHessian,
    BatchGrad,
    BatchL2Grad,
    DiagGGNExact,
    DiagGGNMC,
    DiagHessian,
    SqrtGGNExact,
    SqrtGGNMC,
    SumGradSquared,
    Variance,
)

# Load the MNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])

train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transform)

train_loader = DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=1000, shuffle=False)

# %%
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.network = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 128),  # Input size is 784 (28x28), hidden layer size is 128
            nn.ReLU(),
            nn.Linear(128, 64),   # Second hidden layer size is 64
            nn.ReLU(),
            nn.Linear(64, 10)     # Output layer for 10 classes
        )

    def forward(self, x):
        return self.network(x)

# Instantiate the model
model = SimpleNet()
model = extend(model, use_converter=True) # Extend the loss function

# %%
def train(model, device, train_loader, optimizer, criterion, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        
        # save current parameters
        theta_0 = parameters_to_vector(model.parameters())
        
        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        output = model(data)
        loss = criterion(output, target)
        
        # Backward pass and optimization
        with backpack(
        GGNMP(),
            ):
            loss.backward()
            
        # Extract gradients and convert to a vector
        gradients = parameters_to_vector(param.grad for param in model.parameters() if param.grad is not None)
        
        optimizer.step()
        
        
        d_unnormalized = parameters_to_vector(model.parameters()) - theta_0
        
        d_normalized = d_unnormalized / torch.norm(d_unnormalized)
        
        position = 0 # only for printing
        if batch_idx % 100 == 0:
            print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} '
                  f'({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item():.6f}')
            
            print("Current parameter vector length:", len(theta_0), ", values:", 
                  theta_0[position:position + 5])  # observe a different position each time
            print("d vector unnormalized length:", len(d_unnormalized), ", norm:", torch.norm(d_unnormalized),
                  ", values:", d_unnormalized[position:position + 5])
            print("d vector normalized length:", len(d_normalized), ", norm:", torch.norm(d_normalized),
                  ", values:", d_normalized[position:position + 5])
            print("gradients vector length:", len(gradients), ", values:", gradients[position: position + 5])
        
        total_params = sum(p.numel() for p in model.parameters()) # only for printing
        position = (position + 5) % total_params
def test(model, device, test_loader, criterion):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    accuracy = 100. * correct / len(test_loader.dataset)
    
    print(f'\nTest set: Average loss: {test_loss:.4f}, Accuracy: {correct}/{len(test_loader.dataset)} '
          f'({accuracy:.2f}%)\n')

# %%
# Use CUDA if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to the selected device
model.to(device)

# Set up optimizer and loss function
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0)
criterion = nn.CrossEntropyLoss()
criterion = extend(criterion) # for backpack

# %%
# Number of epochs
num_epochs = 1

# Training and testing loop
for epoch in range(1, num_epochs + 1):
    train(model, device, train_loader, optimizer, criterion, epoch)
    test(model, device, test_loader, criterion)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.301217
# Current parameter vector length: 109386 , values: tensor([ 0.0261, -0.0184, -0.0233,  0.0111,  0.0059], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0071, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([6.7521e-06, 6.7521e-06, 6.7521e-06, 6.7512e-06, 6.7512e-06],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([0.0010, 0.0010, 0.0010, 0.0010, 0.0010], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([-0.0007, -0.0007, -0.0007, -0.0007, -0.0007])
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.884682
# Current parameter vector length: 109386 , values: tensor([ 0.0260, -0.0185, -0.0234,  0.0110,  0.0058], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0132, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([1.4048e-05, 1.4048e-05, 1.4048e-05, 1.4048e-05, 1.4048e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([0.0011, 0.0011, 0.0011, 0.0011, 0.0011], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([-0.0014, -0.0014, -0.0014, -0.0014, -0.0014])
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 1.156007
# Current parameter vector length: 109386 , values: tensor([ 0.0256, -0.0189, -0.0238,  0.0106,  0.0054], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0147, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-4.5411e-06, -4.5411e-06, -4.5411e-06, -4.5421e-06, -4.5416e-06],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-0.0003, -0.0003, -0.0003, -0.0003, -0.0003], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([0.0005, 0.0005, 0.0005, 0.0005, 0.0005])
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.681339
# Current parameter vector length: 109386 , values: tensor([ 0.0253, -0.0192, -0.0241,  0.0103,  0.0051], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0179, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([7.5810e-06, 7.5810e-06, 7.5810e-06, 7.5810e-06, 7.5810e-06],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([0.0004, 0.0004, 0.0004, 0.0004, 0.0004], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([-0.0008, -0.0008, -0.0008, -0.0008, -0.0008])
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.462786
# Current parameter vector length: 109386 , values: tensor([ 0.0250, -0.0195, -0.0244,  0.0100,  0.0048], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0142, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-1.2733e-05, -1.2733e-05, -1.2733e-05, -1.2733e-05, -1.2733e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-0.0009, -0.0009, -0.0009, -0.0009, -0.0009], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([0.0013, 0.0013, 0.0013, 0.0013, 0.0013])
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.449220
# Current parameter vector length: 109386 , values: tensor([ 0.0248, -0.0197, -0.0245,  0.0099,  0.0046], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0175, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([2.4166e-05, 2.4166e-05, 2.4166e-05, 2.4166e-05, 2.4166e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([0.0014, 0.0014, 0.0014, 0.0014, 0.0014], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([-0.0024, -0.0024, -0.0024, -0.0024, -0.0024])
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.426220
# Current parameter vector length: 109386 , values: tensor([ 0.0247, -0.0198, -0.0247,  0.0097,  0.0045], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0171, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-2.0387e-05, -2.0387e-05, -2.0387e-05, -2.0388e-05, -2.0387e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-0.0012, -0.0012, -0.0012, -0.0012, -0.0012], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([0.0020, 0.0020, 0.0020, 0.0020, 0.0020])
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.486043
# Current parameter vector length: 109386 , values: tensor([ 0.0246, -0.0199, -0.0247,  0.0097,  0.0045], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0164, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-1.8058e-05, -1.8058e-05, -1.8058e-05, -1.8059e-05, -1.8059e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-0.0011, -0.0011, -0.0011, -0.0011, -0.0011], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([0.0018, 0.0018, 0.0018, 0.0018, 0.0018])
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.521847
# Current parameter vector length: 109386 , values: tensor([ 0.0246, -0.0199, -0.0248,  0.0096,  0.0044], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0234, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-2.6422e-05, -2.6422e-05, -2.6422e-05, -2.6423e-05, -2.6423e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([-0.0011, -0.0011, -0.0011, -0.0011, -0.0011], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([0.0026, 0.0026, 0.0026, 0.0026, 0.0026])
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.286807
# Current parameter vector length: 109386 , values: tensor([ 0.0247, -0.0198, -0.0246,  0.0098,  0.0046], grad_fn=<SliceBackward0>)
# d vector unnormalized length: 109386 , norm: tensor(0.0144, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([2.1378e-05, 2.1378e-05, 2.1378e-05, 2.1377e-05, 2.1377e-05],
#        grad_fn=<SliceBackward0>)
# d vector normalized length: 109386 , norm: tensor(1.0000, grad_fn=<LinalgVectorNormBackward0>) , values: tensor([0.0015, 0.0015, 0.0015, 0.0015, 0.0015], grad_fn=<SliceBackward0>)
# gradients vector length: 109386 , values: tensor([-0.0021, -0.0021, -0.0021, -0.0021, -0.0021])
#
# Test set: Average loss: 0.0003, Accuracy: 9048/10000 (90.48%)
